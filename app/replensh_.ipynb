# %% [markdown]
# # Stock Replenishment using Stacked LSTM-CNN with Hyperparameter Optimization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from keras import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
from keras.models import load_model
import joblib
import os
import sys
import h5py

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the sales data
df_sales = pd.read_excel('D:\\Python\\VYPER Inventory Replenishment\\raw_data\\gopro_sales_eu.xlsx')
df_sales
# Out:
#      Vyper ID        Shipping Label                  Date Dispatch Date  \
# 0      160902  00340434654112618426            2024-12-19    2024-12-19
# 1      160790  00340434654112618099            2024-12-18    2024-12-19
# 2      160700  00340434654112617832            2024-12-18    2024-12-19
# 3      160622  00340434654112617511            2024-12-18    2024-12-19
# 4      160467  00340434654112618464  2024-12-18T15:43:46Z    2024-12-19
# ..        ...                   ...                   ...           ...
# 760    144201  00340434654112660302            2024-08-27    2024-08-28
# 761    144192  00340434654112660364            2024-08-27    2024-08-28
# 762    144189  00340434654112660241            2024-08-27    2024-08-28
# 763    144160  00340434654112660227            2024-08-27    2024-08-27
# 764    144154  00340434654112660203  2024-08-27T07:17:01Z    2024-08-27
#
#                     Customer Name  \
# 0                     Oscar Opitz
# 1                   Florian Seitz
# 2    Anna Vitvinova-Gerphil Denne
# 3                     Anja Seeber
# 4                   Tobias Wilken
# ..                            ...
# 760               Arturs Fadejevs
# 761                 Kuluclu Yakup
# 762                 Thorsten Jost
# 763              Andreas Wittmann
# 764                Sandra Gaffron
#
#                                       Shipping Address Currency  Amount  \
# 0    Oscar Opitz, Mühlenstr. 63, Wentorf bei Hambur...      EUR  335.29
# 1     Florian Seitz, Grūnental 3, Detmold, DE, 32760,       EUR  335.29
# 2    Anna Vitvinova-Gerphil Denne, Rathausstraße 36...      EUR  176.46
# 3    Anja Seeber, Rudolf-Breitscheid-Str. 14, Ilmen...      EUR  335.29
# 4    Tobias Wilken, Siemensweg 5, Schlosserei Tobia...      EUR   66.55
# ..                                                 ...      ...     ...
# 760  Arturs Fadejevs, Emanuelstr 75, 47178, Duisbur...      EUR    8.39
# 761  Kuluclu Yakup, Gotenstr 21, Gelsenkirchen, DE,...      EUR  336.13
# 762  Thorsten Jost, Mauggen 29b, Bockhorn, DE, 85461,       EUR   71.42
# 763  Andreas Wittmann, Schenkenstr. 11, Michelbach ...      EUR  252.09
# 764  Fabio Knust, Poststraße 23, null, Hamburg, DE,...      EUR  335.29
#
#      Delivery Amount  Discount_amount  ...  Payment Status  Invoice Status  \
# 0                  0              0.0  ...            Paid       PROCESSED
# 1                  0              0.0  ...            Paid       PROCESSED
# 2                  0              0.0  ...            Paid       PROCESSED
# 3                  0              0.0  ...            Paid       PROCESSED
# 4                  0              0.0  ...            Paid       PROCESSED
# ..               ...              ...  ...             ...             ...
# 760                0              0.0  ...            Paid       PROCESSED
# 761                0              0.0  ...            Paid       PROCESSED
# 762                0              0.0  ...            Paid       PROCESSED
# 763                0              0.0  ...            Paid       PROCESSED
# 764                0              0.0  ...            Paid       PROCESSED
#
#           Type            Marketplace      Online Order Id Product Brand  \
# 0      EBAY_DE                 Go Pro       13-12476-90395         GoPro
# 1      EBAY_DE                 Go Pro       17-12470-93600         GoPro
# 2      EBAY_DE                 Go Pro       18-12469-40117         GoPro
# 3      EBAY_DE                 Go Pro       13-12474-91865         GoPro
# 4    AMAZON_DE  Amazon Berlin Silicon  302-7492807-5714725         GoPro
# ..         ...                    ...                  ...           ...
# 760    EBAY_DE                 Go Pro       07-11999-02457         GoPro
# 761    EBAY_DE                 Go Pro       27-11978-05096         GoPro
# 762    EBAY_DE                 Go Pro       07-11998-38078         GoPro
# 763    EBAY_DE                 Go Pro       02-12002-38247         GoPro
# 764  AMAZON_DE  Amazon Berlin Silicon  028-4921051-3368346         GoPro
#
#                                         Product Name           SKU QTY Serials
# 0                GoPro HERO13 Black Accessory Bundle  CHDRB-131-RW   1     NaN
# 1                GoPro HERO13 Black Accessory Bundle  CHDRB-131-RW   1     NaN
# 2                                         GoPro HERO  CHDHF-131-EU   1     NaN
# 3                GoPro HERO13 Black Accessory Bundle  CHDRB-131-RW   1     NaN
# 4          MAX Dual Battery Charger + Enduro Battery  ACDBD-011-EU   1     NaN
# ..                                               ...           ...  ..     ...
# 760                           Head Strap + QuickClip     ACHOM-001   1     NaN
# 761                    HERO12 Black Accessory Bundle  CHDRB-121-RW   1     NaN
# 762                          Media Mod (HERO9 Black)     ADFMD-001   1     NaN
# 763  GoPro HERO10 Black (Without the the Carry Case)  CHDHX-102-RT   1     NaN
# 764                    HERO12 Black Accessory Bundle  CHDRB-121-RW   1     NaN
#
# [765 rows x 22 columns]

# %%
# Drop columns with all NaN values
df_sales.dropna(axis=1, how='all', inplace=True)
df_sales.head()
# Out:
#    Vyper ID        Shipping Label                  Date Dispatch Date  \
# 0    160902  00340434654112618426            2024-12-19    2024-12-19
# 1    160790  00340434654112618099            2024-12-18    2024-12-19
# 2    160700  00340434654112617832            2024-12-18    2024-12-19
# 3    160622  00340434654112617511            2024-12-18    2024-12-19
# 4    160467  00340434654112618464  2024-12-18T15:43:46Z    2024-12-19
#
#                   Customer Name  \
# 0                   Oscar Opitz
# 1                 Florian Seitz
# 2  Anna Vitvinova-Gerphil Denne
# 3                   Anja Seeber
# 4                 Tobias Wilken
#
#                                     Shipping Address Currency  Amount  \
# 0  Oscar Opitz, Mühlenstr. 63, Wentorf bei Hambur...      EUR  335.29
# 1   Florian Seitz, Grūnental 3, Detmold, DE, 32760,       EUR  335.29
# 2  Anna Vitvinova-Gerphil Denne, Rathausstraße 36...      EUR  176.46
# 3  Anja Seeber, Rudolf-Breitscheid-Str. 14, Ilmen...      EUR  335.29
# 4  Tobias Wilken, Siemensweg 5, Schlosserei Tobia...      EUR   66.55
#
#    Delivery Amount  Discount_amount  ...  Full Total  Payment Status  \
# 0                0              0.0  ...      548.90            Paid
# 1                0              0.0  ...      548.90            Paid
# 2                0              0.0  ...      235.63            Paid
# 3                0              0.0  ...      548.90            Paid
# 4                0              0.0  ...       74.96            Paid
#
#   Invoice Status       Type            Marketplace      Online Order Id  \
# 0      PROCESSED    EBAY_DE                 Go Pro       13-12476-90395
# 1      PROCESSED    EBAY_DE                 Go Pro       17-12470-93600
# 2      PROCESSED    EBAY_DE                 Go Pro       18-12469-40117
# 3      PROCESSED    EBAY_DE                 Go Pro       13-12474-91865
# 4      PROCESSED  AMAZON_DE  Amazon Berlin Silicon  302-7492807-5714725
#
#   Product Brand                               Product Name           SKU QTY
# 0         GoPro        GoPro HERO13 Black Accessory Bundle  CHDRB-131-RW   1
# 1         GoPro        GoPro HERO13 Black Accessory Bundle  CHDRB-131-RW   1
# 2         GoPro                                 GoPro HERO  CHDHF-131-EU   1
# 3         GoPro        GoPro HERO13 Black Accessory Bundle  CHDRB-131-RW   1
# 4         GoPro  MAX Dual Battery Charger + Enduro Battery  ACDBD-011-EU   1
#
# [5 rows x 21 columns]

# %%
# Remove '12:35:57+00:00' from 'Date' column
df_sales['Date'] = pd.to_datetime(df_sales['Date'], format='%Y-%m-%d %H:%M:%S')
df_sales['Date'] = df_sales['Date'].astype(str)
df_sales['Date'] = df_sales['Date'].str.split(' ').str[0]
df_sales['Date'] = pd.to_datetime(df_sales['Date'])
df_sales.head()
# Out:
#    Vyper ID        Shipping Label       Date Dispatch Date  \
# 0    160902  00340434654112618426 2024-12-19    2024-12-19
# 1    160790  00340434654112618099 2024-12-18    2024-12-19
# 2    160700  00340434654112617832 2024-12-18    2024-12-19
# 3    160622  00340434654112617511 2024-12-18    2024-12-19
# 4    160467  00340434654112618464 2024-12-18    2024-12-19
#
#                   Customer Name  \
# 0                   Oscar Opitz
# 1                 Florian Seitz
# 2  Anna Vitvinova-Gerphil Denne
# 3                   Anja Seeber
# 4                 Tobias Wilken
#
#                                     Shipping Address Currency  Amount  \
# 0  Oscar Opitz, Mühlenstr. 63, Wentorf bei Hambur...      EUR  335.29
# 1   Florian Seitz, Grūnental 3, Detmold, DE, 32760,       EUR  335.29
# 2  Anna Vitvinova-Gerphil Denne, Rathausstraße 36...      EUR  176.46
# 3  Anja Seeber, Rudolf-Breitscheid-Str. 14, Ilmen...      EUR  335.29
# 4  Tobias Wilken, Siemensweg 5, Schlosserei Tobia...      EUR   66.55
#
#    Delivery Amount  Discount_amount  ...  Full Total  Payment Status  \
# 0                0              0.0  ...      548.90            Paid
# 1                0              0.0  ...      548.90            Paid
# 2                0              0.0  ...      235.63            Paid
# 3                0              0.0  ...      548.90            Paid
# 4                0              0.0  ...       74.96            Paid
#
#   Invoice Status       Type            Marketplace      Online Order Id  \
# 0      PROCESSED    EBAY_DE                 Go Pro       13-12476-90395
# 1      PROCESSED    EBAY_DE                 Go Pro       17-12470-93600
# 2      PROCESSED    EBAY_DE                 Go Pro       18-12469-40117
# 3      PROCESSED    EBAY_DE                 Go Pro       13-12474-91865
# 4      PROCESSED  AMAZON_DE  Amazon Berlin Silicon  302-7492807-5714725
#
#   Product Brand                               Product Name           SKU QTY
# 0         GoPro        GoPro HERO13 Black Accessory Bundle  CHDRB-131-RW   1
# 1         GoPro        GoPro HERO13 Black Accessory Bundle  CHDRB-131-RW   1
# 2         GoPro                                 GoPro HERO  CHDHF-131-EU   1
# 3         GoPro        GoPro HERO13 Black Accessory Bundle  CHDRB-131-RW   1
# 4         GoPro  MAX Dual Battery Charger + Enduro Battery  ACDBD-011-EU   1
#
# [5 rows x 21 columns]

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Vyper ID          765 non-null    int64
#  1   Shipping Label    765 non-null    object
#  2   Date              765 non-null    datetime64[ns]
#  3   Dispatch Date     765 non-null    object
#  4   Customer Name     765 non-null    object
#  5   Shipping Address  765 non-null    object
#  6   Currency          765 non-null    object
#  7   Amount            765 non-null    float64
#  8   Delivery Amount   765 non-null    int64
#  9   Discount_amount   765 non-null    float64
#  10  Tax amount        765 non-null    float64
#  11  Full Total        765 non-null    float64
#  12  Payment Status    765 non-null    object
#  13  Invoice Status    765 non-null    object
#  14  Type              765 non-null    object
#  15  Marketplace       718 non-null    object
#  16  Online Order Id   720 non-null    object
#  17  Product Brand     765 non-null    object
#  18  Product Name      765 non-null    object
#  19  SKU               765 non-null    object
#  20  QTY               765 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(13)
# memory usage: 125.6+ KB

# %%
# Drop unnecessary columns
df_sales.drop(columns=['Vyper ID', 'Shipping Label', 'Dispatch Date', 'Currency', 'Delivery Amount', 
                       'Discount_amount','Payment Status', 'Invoice Status', 'Marketplace', 'Online Order Id','Product Brand'], inplace=True)
df_sales.head()
# Out:
#         Date                 Customer Name  \
# 0 2024-12-19                   Oscar Opitz
# 1 2024-12-18                 Florian Seitz
# 2 2024-12-18  Anna Vitvinova-Gerphil Denne
# 3 2024-12-18                   Anja Seeber
# 4 2024-12-18                 Tobias Wilken
#
#                                     Shipping Address  Amount  Tax amount  \
# 0  Oscar Opitz, Mühlenstr. 63, Wentorf bei Hambur...  335.29      213.61
# 1   Florian Seitz, Grūnental 3, Detmold, DE, 32760,   335.29      213.61
# 2  Anna Vitvinova-Gerphil Denne, Rathausstraße 36...  176.46       59.17
# 3  Anja Seeber, Rudolf-Breitscheid-Str. 14, Ilmen...  335.29      213.61
# 4  Tobias Wilken, Siemensweg 5, Schlosserei Tobia...   66.55        8.41
#
#    Full Total       Type                               Product Name  \
# 0      548.90    EBAY_DE        GoPro HERO13 Black Accessory Bundle
# 1      548.90    EBAY_DE        GoPro HERO13 Black Accessory Bundle
# 2      235.63    EBAY_DE                                 GoPro HERO
# 3      548.90    EBAY_DE        GoPro HERO13 Black Accessory Bundle
# 4       74.96  AMAZON_DE  MAX Dual Battery Charger + Enduro Battery
#
#             SKU  QTY
# 0  CHDRB-131-RW    1
# 1  CHDRB-131-RW    1
# 2  CHDHF-131-EU    1
# 3  CHDRB-131-RW    1
# 4  ACDBD-011-EU    1

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x='Type', y='QTY', data=df_sales, ci=None, estimator=sum, palette='coolwarm')
# Display value on top of each bar
for p in plt.gca().patches:
    plt.gca().annotate(f"{int(p.get_height()):,}", (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=11, color='black', xytext=(0, 5), 
                       textcoords='offset points')
plt.title('Sold Quantity by Type', fontsize=20)
plt.xlabel('Marketplace', fontsize=15)
plt.ylabel('Quantity', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x=df_sales['Date'].dt.month, y='Full Total', data=df_sales, ci=None, estimator=sum, palette='coolwarm')
# Display value on top of each bar
for p in plt.gca().patches:
    plt.gca().annotate(f"{int(p.get_height()):,}", (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=11, color='black', xytext=(0, 5), 
                       textcoords='offset points')
plt.title('Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %%
df_sales.groupby('Date')['Full Total'].sum().plot(kind='line', subplots=True, figsize=(15, 8), color='#e33270')
plt.title('Sales Data')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %%
# Top 5 products by sales
fig, ax = plt.subplots(figsize=(15, 8))
top_5_sales = sns.barplot(data=df_sales.groupby('Product Name')['Full Total'].sum().sort_values(ascending=False).head(5).reset_index(), y='Product Name', x='Full Total', palette='magma')
for p in ax.patches:
    ax.annotate(f"{int(p.get_width()):,}", (p.get_width(), p.get_y() + p.get_height() / 2.), ha='center', va='center', fontsize=12, color='black', xytext=(20, 0), textcoords='offset points')
    
plt.title('Top 5 Products by Sales', fontsize=18)
plt.xlabel('Total Sales', fontsize=14)
plt.ylabel('Product Name', fontsize=14)
plt.show()

# %%
# Top 5 products by quantity
fig, ax = plt.subplots(figsize=(15, 8))
top_5_qty = sns.barplot(data=df_sales.groupby('Product Name')['QTY'].sum().sort_values(ascending=False).head(5).reset_index(), y='Product Name', x='QTY', palette='rocket')
for p in ax.patches:
    ax.annotate(f"{int(p.get_width()):,}", (p.get_width(), p.get_y() + p.get_height() / 2.), ha='center', va='center', fontsize=12, color='black', xytext=(20, 0), textcoords='offset points')
plt.title('Top 5 Products by Quantity', fontsize=18)
plt.xlabel('Total Quantity', fontsize=14)
plt.ylabel('Product Name', fontsize=14)
plt.show()

# %%
# Load Stock Data
df_stock = pd.read_excel('D:\\Python\\VYPER Inventory Replenishment\\raw_data\\gopro_stock_eu.xlsx', skiprows=3)
df_stock.reset_index(drop=True, inplace=True)
df_stock.head()
# Out:
#                    Stock Item Brand Name        SKU  Initial Stock  Stock In  \
# 0          GoPro HERO Session      GoPro  CHDNH-B13            0.0       0.0
# 1    GoPro HERO6 Black Refurb      GoPro  CHDNH-B17            0.0       0.0
# 2  GoPro HERO5 Session Refurb      GoPro  CHDNH-B16            0.0       0.0
# 3    GoPro HERO5 Black Refurb      GoPro  CHDNH-B15            0.0       0.0
# 4    GoPro HERO4 Black Refurb      GoPro  CHDNH-B11            0.0       0.0
#
#    Stock Out  Stock On Hand  Manual Count  Variance    Cost  Total
# 0        0.0            0.0           NaN       NaN   44.62    0.0
# 1        0.0            0.0           NaN       NaN  114.74    0.0
# 2        0.0            0.0           NaN       NaN   81.11    0.0
# 3        0.0            0.0           NaN       NaN   89.24    0.0
# 4        0.0            0.0           NaN       NaN   70.12    0.0

# %%
# Delete last row
df_stock.drop(df_stock.tail(1).index, inplace=True)
df_stock.tail()
# Out:
#                                       Stock Item Brand Name  \
# 311                  HERO 8 Black - Non Packaged      GoPro
# 312   Flexible Grip Mount (Featuring  Gear Ties)      GoPro
# 313               GoPro SWAG - Frisbee/Towel/Box      GoPro
# 314               GoPro HERO13 Black SWAG Bundle      GoPro
# 315                  HERO12 Black - Non Packaged      GoPro
#
#                    SKU  Initial Stock  Stock In  Stock Out  Stock On Hand  \
# 311    CHDHX-801-RW-NP            0.0       0.0        0.0            0.0
# 312          AGRTM-002           12.0       0.0        0.0           12.0
# 313    GP-SWAG-BDL-001          138.0       0.0        0.0          138.0
# 314  CHDHX-131-RW-SWAG            0.0       0.0        0.0            0.0
# 315    CHDHX-121-RW-NP            0.0       0.0        0.0            0.0
#
#      Manual Count  Variance   Cost  Total
# 311           NaN       NaN   0.00    0.0
# 312           NaN       NaN  20.25  243.0
# 313           NaN       NaN   0.00    0.0
# 314           NaN       NaN   0.00    0.0
# 315           NaN       NaN   0.00    0.0

# %%
# Drop columns with all NaN values
df_stock.dropna(axis=1, how='all', inplace=True)
df_stock.head()
# Out:
#                    Stock Item Brand Name        SKU  Initial Stock  Stock In  \
# 0          GoPro HERO Session      GoPro  CHDNH-B13            0.0       0.0
# 1    GoPro HERO6 Black Refurb      GoPro  CHDNH-B17            0.0       0.0
# 2  GoPro HERO5 Session Refurb      GoPro  CHDNH-B16            0.0       0.0
# 3    GoPro HERO5 Black Refurb      GoPro  CHDNH-B15            0.0       0.0
# 4    GoPro HERO4 Black Refurb      GoPro  CHDNH-B11            0.0       0.0
#
#    Stock Out  Stock On Hand    Cost  Total
# 0        0.0            0.0   44.62    0.0
# 1        0.0            0.0  114.74    0.0
# 2        0.0            0.0   81.11    0.0
# 3        0.0            0.0   89.24    0.0
# 4        0.0            0.0   70.12    0.0

# %%
# Convert float64 columns to int64
df_stock = df_stock.astype({'Initial Stock': 'int64','Stock In': 'int64', 'Stock Out': 'int64', 'Stock On Hand': 'int64'})
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stock Item     316 non-null    object
#  1   Brand Name     316 non-null    object
#  2   SKU            316 non-null    object
#  3   Initial Stock  316 non-null    int64
#  4   Stock In       316 non-null    int64
#  5   Stock Out      316 non-null    int64
#  6   Stock On Hand  316 non-null    int64
#  7   Cost           316 non-null    float64
#  8   Total          316 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 22.3+ KB

# %%
# Drop unnecessary columns
df_stock.drop(columns=['Brand Name', 'Initial Stock', 'Stock In', 'Stock Out'], inplace=True)
df_stock.head()
# Out:
#                    Stock Item        SKU  Stock On Hand    Cost  Total
# 0          GoPro HERO Session  CHDNH-B13              0   44.62    0.0
# 1    GoPro HERO6 Black Refurb  CHDNH-B17              0  114.74    0.0
# 2  GoPro HERO5 Session Refurb  CHDNH-B16              0   81.11    0.0
# 3    GoPro HERO5 Black Refurb  CHDNH-B15              0   89.24    0.0
# 4    GoPro HERO4 Black Refurb  CHDNH-B11              0   70.12    0.0

# %%
# Aggregate sales data to daily level
daily_sales = df_sales.groupby('Date')['QTY'].sum().reset_index()

# %% [markdown]
# *  Adding rolling mean and rolling standard deviation features to the dataset.

# %%
# Calculate the rolling statistics
daily_sales['Rolling_Mean_7'] = daily_sales['QTY'].rolling(window=7).mean()
daily_sales['Rolling_Std_7'] = daily_sales['QTY'].rolling(window=7).std()

# Add lag features
daily_sales['Lag_1'] = daily_sales['QTY'].shift(1)
daily_sales['Lag_7'] = daily_sales['QTY'].shift(7)

daily_sales.fillna(0, inplace=True)

# Create additional time-based features
daily_sales['DayOfWeek'] = daily_sales['Date'].dt.dayofweek
daily_sales['Month'] = daily_sales['Date'].dt.month

daily_sales
# Out:
#           Date  QTY  Rolling_Mean_7  Rolling_Std_7  Lag_1  Lag_7  DayOfWeek  \
# 0   2024-08-27    6        0.000000       0.000000    0.0    0.0          1
# 1   2024-08-28    4        0.000000       0.000000    6.0    0.0          2
# 2   2024-08-29   57        0.000000       0.000000    4.0    0.0          3
# 3   2024-08-30    4        0.000000       0.000000   57.0    0.0          4
# 4   2024-08-31    1        0.000000       0.000000    4.0    0.0          5
# ..         ...  ...             ...            ...    ...    ...        ...
# 108 2024-12-15    3        6.571429       6.133437    2.0    7.0          6
# 109 2024-12-16   13        8.285714       5.992058    3.0    1.0          0
# 110 2024-12-17    7        7.714286       5.879747   13.0   11.0          1
# 111 2024-12-18   10        6.714286       4.461475    7.0   17.0          2
# 112 2024-12-19    1        5.428571       4.649629   10.0   10.0          3
#
#      Month
# 0        8
# 1        8
# 2        8
# 3        8
# 4        8
# ..     ...
# 108     12
# 109     12
# 110     12
# 111     12
# 112     12
#
# [113 rows x 8 columns]

# %% [markdown]
# Applying StandardScaler to the dataset.
# - StandardScaler is used to standardize the features by removing the mean and scaling to unit variance.
# - StandardScaler is applied to the features of the dataset.

# %%
# Normalize the data using StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(daily_sales[['QTY', 'Rolling_Mean_7', 'Rolling_Std_7', 'Lag_1', 'Lag_7', 'DayOfWeek', 'Month']])

# %% [markdown]
# Splitting the dataset into training and testing datasets.
#    - The dataset is split into training and testing datasets.
#    - The training dataset is used to train the model.
#    - The testing dataset is used to evaluate the model.
#    - The testing dataset is used to predict the stock replenishment for the next 30 days.

# %%
# Prepare sequences for BiLSTM and Gradient Boosting models
sequence_length = 14
num_features = scaled_data.shape[1]

X, y = [], []
for i in range(len(scaled_data) - sequence_length):
    X.append(scaled_data[i:i+sequence_length])
    y.append(scaled_data[i+sequence_length, 0])

X, y = np.array(X), np.array(y)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False, random_state=42)

# %% [markdown]
# Building a Stacked LSTM-RHN model.
#    - The Stacked LSTM-RHN model is built using the Keras library.
#    - The model is trained on the training dataset.
#    - The model is used to predict the stock replenishment for the next 30 days.

# %%
# Build the LSTM model
lstm_model = Sequential()
lstm_model.add(LSTM(units=540, input_shape=(sequence_length, num_features), return_sequences=False))
lstm_model.add(Dropout(0.2))
lstm_model.add(Dense(64, activation='relu'))
lstm_model.add(Dropout(0.2))
lstm_model.add(Dense(1))  # Output layer
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
lstm_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Save the model
#lstm_model.save('best_lstm_model.h5')

# Make predictions
lstm_test_pred = lstm_model.predict(X_test)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 3s 382ms/step - loss: 1.0561 - val_loss: 0.3675
# Epoch 2/50
# 3/3 [==============================] - 0s 117ms/step - loss: 1.0143 - val_loss: 0.5336
# Epoch 3/50
# 3/3 [==============================] - 0s 107ms/step - loss: 1.0020 - val_loss: 0.4889
# Epoch 4/50
# 3/3 [==============================] - 0s 109ms/step - loss: 0.9567 - val_loss: 0.4975
# Epoch 5/50
# 3/3 [==============================] - 0s 112ms/step - loss: 0.9303 - val_loss: 0.3905
# Epoch 6/50
# 3/3 [==============================] - 0s 112ms/step - loss: 0.9098 - val_loss: 0.4072
# Epoch 7/50
# 3/3 [==============================] - 0s 111ms/step - loss: 0.9366 - val_loss: 0.4230
# Epoch 8/50
# 3/3 [==============================] - 0s 123ms/step - loss: 0.9382 - val_loss: 0.5436
# Epoch 9/50
# 3/3 [==============================] - 0s 131ms/step - loss: 0.8691 - val_loss: 0.4659
# Epoch 10/50
# 3/3 [==============================] - 0s 122ms/step - loss: 0.9251 - val_loss: 0.5690
# Epoch 11/50
# 3/3 [==============================] - 0s 137ms/step - loss: 0.8113 - val_loss: 0.8415
# Epoch 12/50
# 3/3 [==============================] - 0s 104ms/step - loss: 0.9137 - val_loss: 0.8240
# Epoch 13/50
# 3/3 [==============================] - 0s 114ms/step - loss: 0.7500 - val_loss: 0.3166
# Epoch 14/50
# 3/3 [==============================] - 0s 113ms/step - loss: 0.7968 - val_loss: 0.2679
# Epoch 15/50
# 3/3 [==============================] - 0s 108ms/step - loss: 0.8025 - val_loss: 0.3333
# Epoch 16/50
# 3/3 [==============================] - 0s 122ms/step - loss: 0.9491 - val_loss: 0.3571
# Epoch 17/50
# 3/3 [==============================] - 0s 152ms/step - loss: 0.6761 - val_loss: 0.5067
# Epoch 18/50
# 3/3 [==============================] - 0s 113ms/step - loss: 0.6538 - val_loss: 0.4704
# Epoch 19/50
# 3/3 [==============================] - 0s 109ms/step - loss: 0.5581 - val_loss: 0.6557
# Epoch 20/50
# 3/3 [==============================] - 0s 115ms/step - loss: 0.5951 - val_loss: 0.7361
# Epoch 21/50
# 3/3 [==============================] - 0s 134ms/step - loss: 0.4661 - val_loss: 0.4005
# Epoch 22/50
# 3/3 [==============================] - 0s 125ms/step - loss: 0.4854 - val_loss: 0.4229
# Epoch 23/50
# 3/3 [==============================] - 0s 110ms/step - loss: 0.5276 - val_loss: 0.8154
# Epoch 24/50
# 3/3 [==============================] - 0s 124ms/step - loss: 0.7002 - val_loss: 1.0478
# Epoch 25/50
# 3/3 [==============================] - 0s 107ms/step - loss: 0.6830 - val_loss: 0.8339
# Epoch 26/50
# 3/3 [==============================] - 0s 112ms/step - loss: 0.4928 - val_loss: 0.4429
# Epoch 27/50
# 3/3 [==============================] - 0s 139ms/step - loss: 0.5989 - val_loss: 0.4600
# Epoch 28/50
# 3/3 [==============================] - 0s 118ms/step - loss: 0.3946 - val_loss: 0.5512
# Epoch 29/50
# 3/3 [==============================] - 0s 118ms/step - loss: 0.5670 - val_loss: 0.5039
# Epoch 30/50
# 3/3 [==============================] - 0s 112ms/step - loss: 0.5533 - val_loss: 0.5327
# Epoch 31/50
# 3/3 [==============================] - 0s 112ms/step - loss: 0.5242 - val_loss: 0.3536
# Epoch 32/50
# 3/3 [==============================] - 0s 116ms/step - loss: 0.4640 - val_loss: 0.2301
# Epoch 33/50
# 3/3 [==============================] - 0s 115ms/step - loss: 0.4147 - val_loss: 0.2539
# Epoch 34/50
# 3/3 [==============================] - 0s 122ms/step - loss: 0.4670 - val_loss: 0.2430
# Epoch 35/50
# 3/3 [==============================] - 0s 116ms/step - loss: 0.3700 - val_loss: 0.2393
# Epoch 36/50
# 3/3 [==============================] - 0s 114ms/step - loss: 0.3540 - val_loss: 0.2850
# Epoch 37/50
# 3/3 [==============================] - 0s 116ms/step - loss: 0.3199 - val_loss: 0.3701
# Epoch 38/50
# 3/3 [==============================] - 0s 123ms/step - loss: 0.3883 - val_loss: 0.4409
# Epoch 39/50
# 3/3 [==============================] - 0s 128ms/step - loss: 0.3264 - val_loss: 0.4742
# Epoch 40/50
# 3/3 [==============================] - 0s 122ms/step - loss: 0.5125 - val_loss: 0.4095
# Epoch 41/50
# 3/3 [==============================] - 0s 108ms/step - loss: 0.5335 - val_loss: 0.3161
# Epoch 42/50
# 3/3 [==============================] - 0s 113ms/step - loss: 0.5545 - val_loss: 0.2966
# Epoch 43/50
# 3/3 [==============================] - 0s 111ms/step - loss: 0.7222 - val_loss: 0.3126
# Epoch 44/50
# 3/3 [==============================] - 0s 109ms/step - loss: 0.9809 - val_loss: 0.4224
# Epoch 45/50
# 3/3 [==============================] - 0s 139ms/step - loss: 0.8524 - val_loss: 0.7841
# Epoch 46/50
# 3/3 [==============================] - 0s 128ms/step - loss: 0.5483 - val_loss: 1.0243
# Epoch 47/50
# 3/3 [==============================] - 0s 134ms/step - loss: 0.4547 - val_loss: 0.7091
# Epoch 48/50
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2453 - val_loss: 0.5982
# Epoch 49/50
# 3/3 [==============================] - 0s 116ms/step - loss: 0.4849 - val_loss: 0.4853
# Epoch 50/50
# 3/3 [==============================] - 0s 119ms/step - loss: 0.3270 - val_loss: 0.4648
# 1/1 [==============================] - 0s 446ms/step

# %%
# Define CNN model
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=180, kernel_size=3, activation='relu', input_shape=(sequence_length, num_features)))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Flatten())
cnn_model.add(Dense(64, activation='relu'))
cnn_model.add(Dense(1))
cnn_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the cnn_model
cnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Save the cnn_model
#cnn_model.save('best_cnn_model.h5')

# Make predictions
cnn_test_pred = cnn_model.predict(X_test)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 89ms/step - loss: 1.1593 - val_loss: 0.5994
# Epoch 2/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9051 - val_loss: 0.4487
# Epoch 3/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8763 - val_loss: 0.4867
# Epoch 4/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7858 - val_loss: 0.5801
# Epoch 5/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7509 - val_loss: 0.4881
# Epoch 6/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7119 - val_loss: 0.6065
# Epoch 7/50
# 3/3 [==============================] - 0s 38ms/step - loss: 0.6678 - val_loss: 0.5772
# Epoch 8/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6303 - val_loss: 0.5072
# Epoch 9/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5936 - val_loss: 0.6047
# Epoch 10/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5657 - val_loss: 0.7078
# Epoch 11/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.5390 - val_loss: 0.7559
# Epoch 12/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5078 - val_loss: 0.7649
# Epoch 13/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4753 - val_loss: 0.7339
# Epoch 14/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4465 - val_loss: 0.5672
# Epoch 15/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4207 - val_loss: 0.5276
# Epoch 16/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3952 - val_loss: 0.5488
# Epoch 17/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3673 - val_loss: 0.6486
# Epoch 18/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3365 - val_loss: 0.7059
# Epoch 19/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3137 - val_loss: 0.8043
# Epoch 20/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2893 - val_loss: 0.5852
# Epoch 21/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2635 - val_loss: 0.6551
# Epoch 22/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2457 - val_loss: 0.6274
# Epoch 23/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2175 - val_loss: 0.6327
# Epoch 24/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1879 - val_loss: 0.7401
# Epoch 25/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1713 - val_loss: 0.5833
# Epoch 26/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1460 - val_loss: 0.6387
# Epoch 27/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1154 - val_loss: 0.7318
# Epoch 28/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1018 - val_loss: 0.6983
# Epoch 29/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0815 - val_loss: 0.7527
# Epoch 30/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0931 - val_loss: 0.6128
# Epoch 31/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0951 - val_loss: 0.7770
# Epoch 32/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0801 - val_loss: 0.7075
# Epoch 33/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0728 - val_loss: 0.7884
# Epoch 34/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0782 - val_loss: 0.7057
# Epoch 35/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0528 - val_loss: 0.7244
# Epoch 36/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0292 - val_loss: 0.7816
# Epoch 37/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0290 - val_loss: 0.7587
# Epoch 38/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0291 - val_loss: 0.8212
# Epoch 39/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0158 - val_loss: 0.8176
# Epoch 40/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0283 - val_loss: 0.7747
# Epoch 41/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0101 - val_loss: 0.7127
# Epoch 42/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0111 - val_loss: 0.7206
# Epoch 43/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0110 - val_loss: 0.7534
# Epoch 44/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0104 - val_loss: 0.7922
# Epoch 45/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0087 - val_loss: 0.7592
# Epoch 46/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0068 - val_loss: 0.7634
# Epoch 47/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0069 - val_loss: 0.7562
# Epoch 48/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0037 - val_loss: 0.7636
# Epoch 49/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0027 - val_loss: 0.7685
# Epoch 50/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0023 - val_loss: 0.7730
# 1/1 [==============================] - 0s 120ms/step

# %%
# Combine the predictions using column stacking
stacked_predictions = np.column_stack((lstm_test_pred.flatten(), cnn_test_pred.flatten()))

# Train a final regressor on the stacked predictions
final_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
final_regressor.fit(stacked_predictions, y_test)

# Make predictions on the test set
final_pred = final_regressor.predict(stacked_predictions)

# Inverse transform the predictions
final_pred_rescaled = scaler.inverse_transform(np.column_stack([final_pred.reshape(-1, 1),
                                                                np.zeros((final_pred.shape[0], num_features - 1))]))[:, 0]

# %%
# Calculate the evaluation metrics
mae = mean_absolute_error(scaler.inverse_transform(np.column_stack([y_test.reshape(-1, 1),
                                np.zeros((y_test.shape[0], num_features - 1))]))[:, 0], final_pred_rescaled)
mse = mean_squared_error(scaler.inverse_transform(np.column_stack([y_test.reshape(-1, 1),
                                np.zeros((y_test.shape[0], num_features - 1))]))[:, 0], final_pred_rescaled)
r2 = r2_score(scaler.inverse_transform(np.column_stack([y_test.reshape(-1, 1),
                                np.zeros((y_test.shape[0], num_features - 1))]))[:, 0], final_pred_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error: {mae:.2f}')
print(f'Mean Squared Error: {mse:.2f}')
print(f'R2 Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
# Out:
# Mean Absolute Error: 1.38
# Mean Squared Error: 3.55
# R2 Score: 0.85
# Root Mean Squared Error: 1.89

# %%
# Save the stacked model
#joblib.dump(final_regressor, 'stacked_model.pkl')

# %%
# Load the stacked model
#final_regressor = joblib.load('stacked_model.pkl')

# %%
# Forecast next 30 days
future_predictions = []
last_sequence = scaled_data[-sequence_length:]

for _ in range(30):
    # Predict the next value using LSTM and CNN models
    lstm_next_pred = lstm_model.predict(last_sequence.reshape(1, sequence_length, num_features))
    cnn_next_pred = cnn_model.predict(last_sequence.reshape(1, sequence_length, num_features))

    # Combine the predictions using column stacking
    stacked_next_pred = np.column_stack((lstm_next_pred.flatten(), cnn_next_pred.flatten()))
    final_next_pred = final_regressor.predict(stacked_next_pred)

    # Store the final prediction
    future_predictions.append(final_next_pred)

    # Update the sequence
    next_input = np.concatenate([last_sequence[-1, :-1], final_next_pred])
    last_sequence = np.vstack([last_sequence[1:], next_input])

# Convert the future predictions to a single array
future_predictions = np.array(future_predictions).reshape(-1, 1)

# Concatenate zeros to match the original feature shape for inverse transformation
future_predictions_full = np.column_stack([future_predictions, np.zeros((future_predictions.shape[0], num_features - 1))])

# Inverse transform the predictions
future_predictions_rescaled = scaler.inverse_transform(future_predictions_full)
future_predictions_units = future_predictions_rescaled[:, 0]
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
# Plot the results
plt.figure(figsize=(20, 12))
plt.plot(daily_sales['Date'], daily_sales['QTY'], label='Historical Sales')
future_dates = pd.date_range(start=daily_sales['Date'].max() + pd.Timedelta(days=1), periods=30)
plt.plot(future_dates, future_predictions_units, label='Forecasted Sales', linestyle='--', color='#168e72', linewidth=2)
plt.xlabel('Date', fontsize=15)
plt.ylabel('Units', fontsize=15)
plt.title('Stock Inventory Replenishment Forecast with Stacked LSTM-CNN Model', fontsize=20)
plt.legend()
plt.show()

# %%
# Calculate the actual units sold for each SKU in the last 30 days
last_30_days_sales = df_sales[df_sales['Date'] > df_sales['Date'].max() - pd.Timedelta(days=30)]
last_30_days_sales = last_30_days_sales.groupby(['SKU', 'Product Name'])['QTY'].sum().reset_index()
last_30_days_sales.columns = ['SKU', 'Product Name','Last_30_Days_Sales']

# Get the current stock levels for each SKU
current_stock_levels = df_stock.groupby('SKU')['Stock On Hand'].sum().reset_index()
current_stock_levels.columns = ['SKU', 'Current_Stock']

# Merge the last 30 days sales and current stock levels
restock_skus = pd.merge(last_30_days_sales, current_stock_levels, on='SKU')

# Calculate the forecasted demand for the next 30 days based on the model's forecast
average_daily_forecast = future_predictions_units.mean()

# Calculate restock quantity considering forecasted demand and current stock
restock_skus['Restock_Quantity'] = restock_skus.apply(
    lambda x: max(0, x['Last_30_Days_Sales'] - x['Current_Stock'] + average_daily_forecast), axis=1
)

# Set Restock Quantity to whole integer values (rounded up)
restock_skus['Restock_Quantity'] = restock_skus['Restock_Quantity'].apply(np.ceil).astype(int)

# Adjust Restock Quantity to be in multiples of 6
restock_skus['Restock_Quantity'] = restock_skus['Restock_Quantity'].apply(lambda x: x + (6 - x % 6) if x % 6 != 0 else x)

# Ensure Restock Quantity is zero if Current Stock is greater than or equal to Forecasted Demand
restock_skus['Restock_Quantity'] = restock_skus.apply(
    lambda x: 0 if x['Current_Stock'] >= x['Last_30_Days_Sales'] else x['Restock_Quantity'], axis=1
)

# Restock quantity not required for SKUs start with 'UKRFB
restock_skus = restock_skus[~restock_skus['SKU'].str.startswith('UKRFB')]

# Restock quantity not required for SKUs start with 'DERFB'
restock_skus = restock_skus[~restock_skus['SKU'].str.startswith('DERFB')]

# Restock quantity not required for SKUs ends with '- R'
restock_skus = restock_skus[~restock_skus['SKU'].str.endswith('- R')].reset_index(drop=True)

# Display the SKUs that need restocking with the calculated restock quantities
print("SKUs that need restocking with required quantities:")
display(restock_skus[['SKU', 'Product Name', 'Last_30_Days_Sales', 'Current_Stock', 'Restock_Quantity']])
# Out:
# SKUs that need restocking with required quantities:
#                     SKU                                       Product Name  \
# 0             ABSSC-002                                        GoPro Casey
# 1             ACBAT-011                                 MAX Enduro Battery
# 2          ACDBD-011-EU          MAX Dual Battery Charger + Enduro Battery
# 3             ADBAT-011  GoPro Enduro Rechargeable Li-Ion Battery for H...
# 4             ADCOD-001                USB Pass-Through Door (HERO9 Black)
# 5          ADDBD-211-EU                      Dual Battery Charger + Enduro
# 6             ADFMD-001                            Media Mod (HERO9 Black)
# 7             ADSST-001               Sleeve + Lanyard (HERO9 Black) Black
# 8             ADWAL-001                           HERO9 BLACK Max Lens Mod
# 9             AEBAT-001                            Enduro for HERO13 Black
# 10            AEBAT-201                   Enduro (2 Pack) for HERO13 Black
# 11            AEXTM-011                          Boom + Bar Mount Camera\t
# 12            AFAEM-002                               GoPro 3-Way Grip 2.0
# 13            AFFRC-002                           Protective Sleeve (HERO)
# 14            AGCHM-001             GoPro Chesty (Performance Chest Mount)
# 15            AGRTM-001                             Gumby (Flexible Mount)
# 16            AGTSM-001                  Handlebar / Seatpost / Pole Mount
# 17            AHFSM-001                          Helmet Front + Side Mount
# 18         APHGM-001-EU                                              Volta
# 19         ARMTE-003-EU                               Smart Remote - GoPro
# 20            AUCMT-302                                        Suction Cup
# 21         CHDFB-131-EU                       GoPro HERO13 Creator Edition
# 22         CHDHF-131-EU                                         GoPro HERO
# 23         CHDHX-102-RT    GoPro HERO10 Black (Without the the Carry Case)
# 24         CHDHX-121-RW                                       HERO12 Black
# 25  CHDHX-121-RW-NP-OLD                        HERO12 Black - Non Packaged
# 26         CHDHX-131-RW                                 GoPro HERO13 Black
# 27    CHDHX-131-RW-SWAG                     GoPro HERO13 Black SWAG Bundle
# 28         CHDRB-131-RW                GoPro HERO13 Black Accessory Bundle
#
#     Last_30_Days_Sales  Current_Stock  Restock_Quantity
# 0                   39             10                42
# 1                    3              8                 0
# 2                    1             11                 0
# 3                    4             13                 0
# 4                    9              2                18
# 5                    6              2                12
# 6                    4              3                12
# 7                    3             15                 0
# 8                    3              9                 0
# 9                    2            148                 0
# 10                   3             22                 0
# 11                   1              3                 0
# 12                   2              4                 0
# 13                   1             10                 0
# 14                   5              8                 0
# 15                   3              2                12
# 16                   4              8                 0
# 17                   2              2                 0
# 18                   1              7                 0
# 19                   2              5                 0
# 20                   2              1                12
# 21                  15             12                12
# 22                  14             25                 0
# 23                   1              4                 0
# 24                  39             17                30
# 25                   2              3                 0
# 26                   7            144                 0
# 27                   6              0                18
# 28                  83             10                84

# %%
average_daily_forecast
# Out:
# 7.030333333333336

# %%
# Highlight the SKUs that need restocking above a certain threshold with a color
def highlight_restock(x):
    color = 'background-color: #12A189' if x['Restock_Quantity'] > 0 else ''
    return [color for _ in x]

restock_skus.style.apply(highlight_restock, axis=1)
# Out:
# <style type="text/css">
# #T_f4c1b_row0_col0, #T_f4c1b_row0_col1, #T_f4c1b_row0_col2, #T_f4c1b_row0_col3, #T_f4c1b_row0_col4, #T_f4c1b_row4_col0, #T_f4c1b_row4_col1, #T_f4c1b_row4_col2, #T_f4c1b_row4_col3, #T_f4c1b_row4_col4, #T_f4c1b_row5_col0, #T_f4c1b_row5_col1, #T_f4c1b_row5_col2, #T_f4c1b_row5_col3, #T_f4c1b_row5_col4, #T_f4c1b_row6_col0, #T_f4c1b_row6_col1, #T_f4c1b_row6_col2, #T_f4c1b_row6_col3, #T_f4c1b_row6_col4, #T_f4c1b_row15_col0, #T_f4c1b_row15_col1, #T_f4c1b_row15_col2, #T_f4c1b_row15_col3, #T_f4c1b_row15_col4, #T_f4c1b_row20_col0, #T_f4c1b_row20_col1, #T_f4c1b_row20_col2, #T_f4c1b_row20_col3, #T_f4c1b_row20_col4, #T_f4c1b_row21_col0, #T_f4c1b_row21_col1, #T_f4c1b_row21_col2, #T_f4c1b_row21_col3, #T_f4c1b_row21_col4, #T_f4c1b_row24_col0, #T_f4c1b_row24_col1, #T_f4c1b_row24_col2, #T_f4c1b_row24_col3, #T_f4c1b_row24_col4, #T_f4c1b_row27_col0, #T_f4c1b_row27_col1, #T_f4c1b_row27_col2, #T_f4c1b_row27_col3, #T_f4c1b_row27_col4, #T_f4c1b_row28_col0, #T_f4c1b_row28_col1, #T_f4c1b_row28_col2, #T_f4c1b_row28_col3, #T_f4c1b_row28_col4 {
#   background-color: #12A189;
# }
# </style>
# <table id="T_f4c1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4c1b_level0_col0" class="col_heading level0 col0" >SKU</th>
#       <th id="T_f4c1b_level0_col1" class="col_heading level0 col1" >Product Name</th>
#       <th id="T_f4c1b_level0_col2" class="col_heading level0 col2" >Last_30_Days_Sales</th>
#       <th id="T_f4c1b_level0_col3" class="col_heading level0 col3" >Current_Stock</th>
#       <th id="T_f4c1b_level0_col4" class="col_heading level0 col4" >Restock_Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4c1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4c1b_row0_col0" class="data row0 col0" >ABSSC-002</td>
#       <td id="T_f4c1b_row0_col1" class="data row0 col1" >GoPro Casey</td>
#       <td id="T_f4c1b_row0_col2" class="data row0 col2" >39</td>
#       <td id="T_f4c1b_row0_col3" class="data row0 col3" >10</td>
#       <td id="T_f4c1b_row0_col4" class="data row0 col4" >42</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4c1b_row1_col0" class="data row1 col0" >ACBAT-011</td>
#       <td id="T_f4c1b_row1_col1" class="data row1 col1" >MAX Enduro Battery</td>
#       <td id="T_f4c1b_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_f4c1b_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_f4c1b_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f4c1b_row2_col0" class="data row2 col0" >ACDBD-011-EU</td>
#       <td id="T_f4c1b_row2_col1" class="data row2 col1" >MAX Dual Battery Charger + Enduro Battery</td>
#       <td id="T_f4c1b_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_f4c1b_row2_col3" class="data row2 col3" >11</td>
#       <td id="T_f4c1b_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f4c1b_row3_col0" class="data row3 col0" >ADBAT-011</td>
#       <td id="T_f4c1b_row3_col1" class="data row3 col1" >GoPro Enduro Rechargeable Li-Ion Battery for HERO9/10 Black</td>
#       <td id="T_f4c1b_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_f4c1b_row3_col3" class="data row3 col3" >13</td>
#       <td id="T_f4c1b_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f4c1b_row4_col0" class="data row4 col0" >ADCOD-001</td>
#       <td id="T_f4c1b_row4_col1" class="data row4 col1" >USB Pass-Through Door (HERO9 Black)</td>
#       <td id="T_f4c1b_row4_col2" class="data row4 col2" >9</td>
#       <td id="T_f4c1b_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_f4c1b_row4_col4" class="data row4 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f4c1b_row5_col0" class="data row5 col0" >ADDBD-211-EU</td>
#       <td id="T_f4c1b_row5_col1" class="data row5 col1" >Dual Battery Charger + Enduro</td>
#       <td id="T_f4c1b_row5_col2" class="data row5 col2" >6</td>
#       <td id="T_f4c1b_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_f4c1b_row5_col4" class="data row5 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f4c1b_row6_col0" class="data row6 col0" >ADFMD-001</td>
#       <td id="T_f4c1b_row6_col1" class="data row6 col1" >Media Mod (HERO9 Black)</td>
#       <td id="T_f4c1b_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_f4c1b_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_f4c1b_row6_col4" class="data row6 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f4c1b_row7_col0" class="data row7 col0" >ADSST-001</td>
#       <td id="T_f4c1b_row7_col1" class="data row7 col1" >Sleeve + Lanyard (HERO9 Black) Black</td>
#       <td id="T_f4c1b_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_f4c1b_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_f4c1b_row7_col4" class="data row7 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f4c1b_row8_col0" class="data row8 col0" >ADWAL-001</td>
#       <td id="T_f4c1b_row8_col1" class="data row8 col1" >HERO9 BLACK Max Lens Mod</td>
#       <td id="T_f4c1b_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_f4c1b_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_f4c1b_row8_col4" class="data row8 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f4c1b_row9_col0" class="data row9 col0" >AEBAT-001</td>
#       <td id="T_f4c1b_row9_col1" class="data row9 col1" >Enduro for HERO13 Black</td>
#       <td id="T_f4c1b_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_f4c1b_row9_col3" class="data row9 col3" >148</td>
#       <td id="T_f4c1b_row9_col4" class="data row9 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f4c1b_row10_col0" class="data row10 col0" >AEBAT-201</td>
#       <td id="T_f4c1b_row10_col1" class="data row10 col1" >Enduro (2 Pack) for HERO13 Black</td>
#       <td id="T_f4c1b_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_f4c1b_row10_col3" class="data row10 col3" >22</td>
#       <td id="T_f4c1b_row10_col4" class="data row10 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f4c1b_row11_col0" class="data row11 col0" >AEXTM-011</td>
#       <td id="T_f4c1b_row11_col1" class="data row11 col1" >Boom + Bar Mount Camera	</td>
#       <td id="T_f4c1b_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_f4c1b_row11_col3" class="data row11 col3" >3</td>
#       <td id="T_f4c1b_row11_col4" class="data row11 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f4c1b_row12_col0" class="data row12 col0" >AFAEM-002</td>
#       <td id="T_f4c1b_row12_col1" class="data row12 col1" >GoPro 3-Way Grip 2.0</td>
#       <td id="T_f4c1b_row12_col2" class="data row12 col2" >2</td>
#       <td id="T_f4c1b_row12_col3" class="data row12 col3" >4</td>
#       <td id="T_f4c1b_row12_col4" class="data row12 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4c1b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f4c1b_row13_col0" class="data row13 col0" >AFFRC-002</td>
#       <td id="T_f4c1b_row13_col1" class="data row13 col1" >Protective Sleeve (HERO)</td>
#       <td id="T_f4c1b_row13_col2" class="data row13 col2" >1</td>
#       <td id="T_f4c1b_row13_col3" class="data row13 col3" >10</td>
#       <td id="T_f4c1b_row13_col4" class="data row13 col4" >0</td>

# %%
# save the restock quantities to a CSV file with highlighted colors
restock_skus.style.apply(highlight_restock, axis=1).to_excel('restock_quantities.xlsx', index=False)
