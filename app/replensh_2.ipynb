# %% [markdown]
# # Stock Replenishment using Stacked LSTM-CNN with Hyperparameter Optimization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping
import keras_tuner as kt

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the sales data
df_sales = pd.read_excel('D:\\Python\\VYPER Inventory Replenishment\\raw_data\\gopro_sales_uk.xlsx')
df_sales
# Out:
#      Vyper ID Shipping Label                  Date Dispatch Date  \
# 0      160816  GG434579491GB  2024-12-19T00:03:00Z    2024-12-19
# 1      159928  OM393362997GB            2024-12-17    2024-12-18
# 2      159927  OM393362983GB            2024-12-17    2024-12-18
# 3      159746  OM393362970GB            2024-12-17    2024-12-18
# 4      159659  OM393362780GB            2024-12-17    2024-12-17
# ..        ...            ...                   ...           ...
# 475    149509  GG434562465GB  2024-10-26T13:02:05Z    2024-10-28
# 476    149508  GG434562451GB  2024-10-26T12:04:33Z    2024-10-28
# 477    149503  GG434562448GB  2024-10-26T11:13:10Z    2024-10-28
# 478    149502  JY833553511GB            2024-10-26    2024-10-28
# 479    149495  GG434562403GB  2024-10-26T07:23:59Z    2024-10-28
#
#       Customer Name                                   Shipping Address  \
# 0      Sharon Davis  Josh Davis, 28 WEST ROAD, null, BURY ST. EDMUN...
# 1    Charlie Fowler  Charlie Fowler, 9 Baliol Road, Newton Aycliffe...
# 2          Ian Cale  Ian Cale, No.3 Southsea Street, Manchester, GB...
# 3    MONIKA RAZNIAK  MONIKA RAZNIAK, 55 LANETHORPE CRESCENT, DARLIN...
# 4    David J Hudson  David J Hudson, 12 Russell Crescent, Trimdon S...
# ..              ...                                                ...
# 475  Soheil Torfakh  Soheil, 14 GIBBS YARD 15, CROSS BEDFORD STREET...
# 476           Mason  Mason Bamford, THE COTTAGE, BUTCHERS LANE PYTC...
# 477      Fred banks  Fred banks, 130, RUGBY ROAD, DAGENHAM, GB, GB,...
# 478  Robert Stanley  Robert Stanley, 21 Rock Road, Solihull, West M...
# 479    Anita Powell  Anita Powell, 111 MERCER WAY, null, ROMSEY, GB...
#
#     Currency  Amount  Delivery Amount  Discount_amount  ...  Payment Status  \
# 0        GBP   79.16                0                0  ...            Paid
# 1        GBP  208.33                0                0  ...            Paid
# 2        GBP  274.99                0                0  ...            Paid
# 3        GBP   24.16                0                0  ...            Paid
# 4        GBP   24.99                0                0  ...            Paid
# ..       ...     ...              ...              ...  ...             ...
# 475      GBP   35.82                0                0  ...            Paid
# 476      GBP   27.49                0                0  ...            Paid
# 477      GBP   34.99                0                0  ...            Paid
# 478      GBP   20.83                0                0  ...            Paid
# 479      GBP   27.49                0                0  ...            Paid
#
#      Invoice Status          Type   Marketplace      Online Order Id  \
# 0         PROCESSED  AMAZON_CO.UK  Vyper Global  204-3637982-5834702
# 1         PROCESSED       EBAY_GB        Go Pro       09-12474-83965
# 2         PROCESSED       EBAY_GB        Go Pro       26-12455-84311
# 3         PROCESSED       EBAY_GB        Go Pro       12-12470-68814
# 4         PROCESSED       EBAY_GB        Go Pro       12-12470-26165
# ..              ...           ...           ...                  ...
# 475       PROCESSED  AMAZON_CO.UK  Vyper Global  026-3831446-3397929
# 476       PROCESSED  AMAZON_CO.UK  Vyper Global  202-3687229-5801159
# 477       PROCESSED  AMAZON_CO.UK  Vyper Global  206-3805773-7805122
# 478       PROCESSED       EBAY_GB        Go Pro       08-12242-97485
# 479       PROCESSED  AMAZON_CO.UK  Vyper Global  202-0479917-0954741
#
#     Product Brand                                       Product Name  \
# 0           GoPro                                Ultra Wide Lens Mod
# 1           GoPro                                  HERO11 Black Mini
# 2           GoPro                     GoPro HERO13 Black SWAG Bundle
# 3           GoPro                                     Head Strap 2.0
# 4           GoPro                            Enduro for HERO13 Black
# ..            ...                                                ...
# 475         GoPro                                        GoPro Casey
# 476         GoPro             GoPro Chesty (Performance Chest Mount)
# 477         GoPro                                 Hand + Wrist Strap
# 478         GoPro  GoPro Enduro Rechargeable Li-Ion Battery for H...
# 479         GoPro             GoPro Chesty (Performance Chest Mount)
#
#                    SKU QTY Serials
# 0            AEWAL-001   1     NaN
# 1         CHDHF-111-RW   1     NaN
# 2    CHDHX-131-RW-SWAG   1     NaN
# 3            ACHOM-002   1     NaN
# 4            AEBAT-001   1     NaN
# ..                 ...  ..     ...
# 475          ABSSC-002   1     NaN
# 476          AGCHM-001   1     NaN
# 477          AHWBM-002   1     NaN
# 478          ADBAT-011   1     NaN
# 479          AGCHM-001   1     NaN
#
# [480 rows x 22 columns]

# %%
# Drop columns with all NaN values
df_sales.dropna(axis=1, how='all', inplace=True)
df_sales.head()
# Out:
#    Vyper ID Shipping Label                  Date Dispatch Date  \
# 0    160816  GG434579491GB  2024-12-19T00:03:00Z    2024-12-19
# 1    159928  OM393362997GB            2024-12-17    2024-12-18
# 2    159927  OM393362983GB            2024-12-17    2024-12-18
# 3    159746  OM393362970GB            2024-12-17    2024-12-18
# 4    159659  OM393362780GB            2024-12-17    2024-12-17
#
#     Customer Name                                   Shipping Address Currency  \
# 0    Sharon Davis  Josh Davis, 28 WEST ROAD, null, BURY ST. EDMUN...      GBP
# 1  Charlie Fowler  Charlie Fowler, 9 Baliol Road, Newton Aycliffe...      GBP
# 2        Ian Cale  Ian Cale, No.3 Southsea Street, Manchester, GB...      GBP
# 3  MONIKA RAZNIAK  MONIKA RAZNIAK, 55 LANETHORPE CRESCENT, DARLIN...      GBP
# 4  David J Hudson  David J Hudson, 12 Russell Crescent, Trimdon S...      GBP
#
#    Amount  Delivery Amount  Discount_amount  ...  Full Total  Payment Status  \
# 0   79.16                0                0  ...       91.69            Paid
# 1  208.33                0                0  ...      295.12            Paid
# 2  274.99                0                0  ...      426.23            Paid
# 3   24.16                0                0  ...       25.33            Paid
# 4   24.99                0                0  ...       26.24            Paid
#
#   Invoice Status          Type   Marketplace      Online Order Id  \
# 0      PROCESSED  AMAZON_CO.UK  Vyper Global  204-3637982-5834702
# 1      PROCESSED       EBAY_GB        Go Pro       09-12474-83965
# 2      PROCESSED       EBAY_GB        Go Pro       26-12455-84311
# 3      PROCESSED       EBAY_GB        Go Pro       12-12470-68814
# 4      PROCESSED       EBAY_GB        Go Pro       12-12470-26165
#
#   Product Brand                    Product Name                SKU QTY
# 0         GoPro             Ultra Wide Lens Mod          AEWAL-001   1
# 1         GoPro               HERO11 Black Mini       CHDHF-111-RW   1
# 2         GoPro  GoPro HERO13 Black SWAG Bundle  CHDHX-131-RW-SWAG   1
# 3         GoPro                  Head Strap 2.0          ACHOM-002   1
# 4         GoPro         Enduro for HERO13 Black          AEBAT-001   1
#
# [5 rows x 21 columns]

# %%
# Remove '12:35:57+00:00' from 'Date' column
df_sales['Date'] = pd.to_datetime(df_sales['Date'], format='%Y-%m-%d %H:%M:%S')
df_sales['Date'] = df_sales['Date'].astype(str)
df_sales['Date'] = df_sales['Date'].str.split(' ').str[0]
df_sales['Date'] = pd.to_datetime(df_sales['Date'])
df_sales.head()
# Out:
#    Vyper ID Shipping Label       Date Dispatch Date   Customer Name  \
# 0    160816  GG434579491GB 2024-12-19    2024-12-19    Sharon Davis
# 1    159928  OM393362997GB 2024-12-17    2024-12-18  Charlie Fowler
# 2    159927  OM393362983GB 2024-12-17    2024-12-18        Ian Cale
# 3    159746  OM393362970GB 2024-12-17    2024-12-18  MONIKA RAZNIAK
# 4    159659  OM393362780GB 2024-12-17    2024-12-17  David J Hudson
#
#                                     Shipping Address Currency  Amount  \
# 0  Josh Davis, 28 WEST ROAD, null, BURY ST. EDMUN...      GBP   79.16
# 1  Charlie Fowler, 9 Baliol Road, Newton Aycliffe...      GBP  208.33
# 2  Ian Cale, No.3 Southsea Street, Manchester, GB...      GBP  274.99
# 3  MONIKA RAZNIAK, 55 LANETHORPE CRESCENT, DARLIN...      GBP   24.16
# 4  David J Hudson, 12 Russell Crescent, Trimdon S...      GBP   24.99
#
#    Delivery Amount  Discount_amount  ...  Full Total  Payment Status  \
# 0                0                0  ...       91.69            Paid
# 1                0                0  ...      295.12            Paid
# 2                0                0  ...      426.23            Paid
# 3                0                0  ...       25.33            Paid
# 4                0                0  ...       26.24            Paid
#
#   Invoice Status          Type   Marketplace      Online Order Id  \
# 0      PROCESSED  AMAZON_CO.UK  Vyper Global  204-3637982-5834702
# 1      PROCESSED       EBAY_GB        Go Pro       09-12474-83965
# 2      PROCESSED       EBAY_GB        Go Pro       26-12455-84311
# 3      PROCESSED       EBAY_GB        Go Pro       12-12470-68814
# 4      PROCESSED       EBAY_GB        Go Pro       12-12470-26165
#
#   Product Brand                    Product Name                SKU QTY
# 0         GoPro             Ultra Wide Lens Mod          AEWAL-001   1
# 1         GoPro               HERO11 Black Mini       CHDHF-111-RW   1
# 2         GoPro  GoPro HERO13 Black SWAG Bundle  CHDHX-131-RW-SWAG   1
# 3         GoPro                  Head Strap 2.0          ACHOM-002   1
# 4         GoPro         Enduro for HERO13 Black          AEBAT-001   1
#
# [5 rows x 21 columns]

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Vyper ID          480 non-null    int64
#  1   Shipping Label    480 non-null    object
#  2   Date              480 non-null    datetime64[ns]
#  3   Dispatch Date     480 non-null    object
#  4   Customer Name     480 non-null    object
#  5   Shipping Address  480 non-null    object
#  6   Currency          480 non-null    object
#  7   Amount            480 non-null    float64
#  8   Delivery Amount   480 non-null    int64
#  9   Discount_amount   480 non-null    int64
#  10  Tax amount        480 non-null    float64
#  11  Full Total        480 non-null    float64
#  12  Payment Status    480 non-null    object
#  13  Invoice Status    480 non-null    object
#  14  Type              480 non-null    object
#  15  Marketplace       460 non-null    object
#  16  Online Order Id   460 non-null    object
#  17  Product Brand     480 non-null    object
#  18  Product Name      480 non-null    object
#  19  SKU               480 non-null    object
#  20  QTY               480 non-null    int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(13)
# memory usage: 78.9+ KB

# %%
# Drop unnecessary columns
df_sales.drop(columns=['Vyper ID', 'Shipping Label', 'Dispatch Date', 'Currency', 'Delivery Amount', 
                       'Discount_amount','Payment Status', 'Invoice Status', 'Marketplace', 'Online Order Id','Product Brand'], inplace=True)
df_sales.head()
# Out:
#         Date   Customer Name  \
# 0 2024-12-19    Sharon Davis
# 1 2024-12-17  Charlie Fowler
# 2 2024-12-17        Ian Cale
# 3 2024-12-17  MONIKA RAZNIAK
# 4 2024-12-17  David J Hudson
#
#                                     Shipping Address  Amount  Tax amount  \
# 0  Josh Davis, 28 WEST ROAD, null, BURY ST. EDMUN...   79.16       12.53
# 1  Charlie Fowler, 9 Baliol Road, Newton Aycliffe...  208.33       86.79
# 2  Ian Cale, No.3 Southsea Street, Manchester, GB...  274.99      151.24
# 3  MONIKA RAZNIAK, 55 LANETHORPE CRESCENT, DARLIN...   24.16        1.17
# 4  David J Hudson, 12 Russell Crescent, Trimdon S...   24.99        1.25
#
#    Full Total          Type                    Product Name  \
# 0       91.69  AMAZON_CO.UK             Ultra Wide Lens Mod
# 1      295.12       EBAY_GB               HERO11 Black Mini
# 2      426.23       EBAY_GB  GoPro HERO13 Black SWAG Bundle
# 3       25.33       EBAY_GB                  Head Strap 2.0
# 4       26.24       EBAY_GB         Enduro for HERO13 Black
#
#                  SKU  QTY
# 0          AEWAL-001    1
# 1       CHDHF-111-RW    1
# 2  CHDHX-131-RW-SWAG    1
# 3          ACHOM-002    1
# 4          AEBAT-001    1

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x='Type', y='QTY', data=df_sales, ci=None, estimator=sum, palette='coolwarm')
# Display value on top of each bar
for p in plt.gca().patches:
    plt.gca().annotate(f"{int(p.get_height()):,}", (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=11, color='black', xytext=(0, 5), 
                       textcoords='offset points')
plt.title('Sold Quantity by Type', fontsize=20)
plt.xlabel('Marketplace', fontsize=15)
plt.ylabel('Quantity', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x=df_sales['Date'].dt.month, y='Full Total', data=df_sales, ci=None, estimator=sum, palette='coolwarm')
# Display value on top of each bar
for p in plt.gca().patches:
    plt.gca().annotate(f"{int(p.get_height()):,}", (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=11, color='black', xytext=(0, 5), 
                       textcoords='offset points')
plt.title('Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %%
df_sales.groupby('Date')['Full Total'].sum().plot(kind='line', subplots=True, figsize=(15, 8), color='#e33270')
plt.title('Sales Data')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %%
# Top 5 products by sales
fig, ax = plt.subplots(figsize=(15, 8))
top_5_sales = sns.barplot(data=df_sales.groupby('Product Name')['Full Total'].sum().sort_values(ascending=False).head(5).reset_index(), y='Product Name', x='Full Total', palette='magma')
for p in ax.patches:
    ax.annotate(f"{int(p.get_width()):,}", (p.get_width(), p.get_y() + p.get_height() / 2.), ha='center', va='center', fontsize=12, color='black', xytext=(20, 0), textcoords='offset points')
    
plt.title('Top 5 Products by Sales', fontsize=18)
plt.xlabel('Total Sales', fontsize=14)
plt.ylabel('Product Name', fontsize=14)
plt.show()

# %%
# Top 5 products by quantity
fig, ax = plt.subplots(figsize=(15, 8))
top_5_qty = sns.barplot(data=df_sales.groupby('Product Name')['QTY'].sum().sort_values(ascending=False).head(5).reset_index(), y='Product Name', x='QTY', palette='rocket')
for p in ax.patches:
    ax.annotate(f"{int(p.get_width()):,}", (p.get_width(), p.get_y() + p.get_height() / 2.), ha='center', va='center', fontsize=12, color='black', xytext=(20, 0), textcoords='offset points')
plt.title('Top 5 Products by Quantity', fontsize=18)
plt.xlabel('Total Quantity', fontsize=14)
plt.ylabel('Product Name', fontsize=14)
plt.show()

# %%
# Load Stock Data
df_stock = pd.read_excel('D:\\Python\\VYPER Inventory Replenishment\\raw_data\\gopro_stock_uk.xlsx', skiprows=3)
df_stock.reset_index(drop=True, inplace=True)
df_stock.head()
# Out:
#                    Stock Item Brand Name        SKU  Initial Stock  Stock In  \
# 0          GoPro HERO Session      GoPro  CHDNH-B13            0.0       0.0
# 1    GoPro HERO6 Black Refurb      GoPro  CHDNH-B17            0.0       0.0
# 2  GoPro HERO5 Session Refurb      GoPro  CHDNH-B16           -1.0       0.0
# 3    GoPro HERO5 Black Refurb      GoPro  CHDNH-B15           -2.0       0.0
# 4    GoPro HERO4 Black Refurb      GoPro  CHDNH-B11            0.0       0.0
#
#    Stock Out  Stock On Hand  Manual Count  Variance   Cost  Total
# 0        0.0            0.0           NaN       NaN  40.28   0.00
# 1        0.0            0.0           NaN       NaN   0.00   0.00
# 2        0.0           -1.0           NaN       NaN  69.75 -69.75
# 3        0.0           -2.0           NaN       NaN   0.00   0.00
# 4        0.0            0.0           NaN       NaN   0.00   0.00

# %%
# Delete last row
df_stock.drop(df_stock.tail(1).index, inplace=True)
df_stock.tail()
# Out:
#                                       Stock Item Brand Name  \
# 311                  HERO 8 Black - Non Packaged      GoPro
# 312   Flexible Grip Mount (Featuring  Gear Ties)      GoPro
# 313               GoPro SWAG - Frisbee/Towel/Box      GoPro
# 314               GoPro HERO13 Black SWAG Bundle      GoPro
# 315                  HERO12 Black - Non Packaged      GoPro
#
#                    SKU  Initial Stock  Stock In  Stock Out  Stock On Hand  \
# 311    CHDHX-801-RW-NP            0.0       0.0        0.0            0.0
# 312          AGRTM-002            6.0       0.0        0.0            6.0
# 313    GP-SWAG-BDL-001           49.0       0.0        0.0           49.0
# 314  CHDHX-131-RW-SWAG            0.0       0.0        0.0            0.0
# 315    CHDHX-121-RW-NP            0.0       0.0        0.0            0.0
#
#      Manual Count  Variance     Cost     Total
# 311           NaN       NaN   0.0000    0.0000
# 312           NaN       NaN  17.0252  102.1512
# 313           NaN       NaN   0.0000    0.0000
# 314           NaN       NaN   0.0000    0.0000
# 315           NaN       NaN   0.0000    0.0000

# %%
# Drop columns with all NaN values
df_stock.dropna(axis=1, how='all', inplace=True)
df_stock.head()
# Out:
#                    Stock Item Brand Name        SKU  Initial Stock  Stock In  \
# 0          GoPro HERO Session      GoPro  CHDNH-B13            0.0       0.0
# 1    GoPro HERO6 Black Refurb      GoPro  CHDNH-B17            0.0       0.0
# 2  GoPro HERO5 Session Refurb      GoPro  CHDNH-B16           -1.0       0.0
# 3    GoPro HERO5 Black Refurb      GoPro  CHDNH-B15           -2.0       0.0
# 4    GoPro HERO4 Black Refurb      GoPro  CHDNH-B11            0.0       0.0
#
#    Stock Out  Stock On Hand   Cost  Total
# 0        0.0            0.0  40.28   0.00
# 1        0.0            0.0   0.00   0.00
# 2        0.0           -1.0  69.75 -69.75
# 3        0.0           -2.0   0.00   0.00
# 4        0.0            0.0   0.00   0.00

# %%
# Convert float64 columns to int64
df_stock = df_stock.astype({'Initial Stock': 'int64','Stock In': 'int64', 'Stock Out': 'int64', 'Stock On Hand': 'int64'})
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stock Item     316 non-null    object
#  1   Brand Name     316 non-null    object
#  2   SKU            316 non-null    object
#  3   Initial Stock  316 non-null    int64
#  4   Stock In       316 non-null    int64
#  5   Stock Out      316 non-null    int64
#  6   Stock On Hand  316 non-null    int64
#  7   Cost           316 non-null    float64
#  8   Total          316 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 22.3+ KB

# %%
# Drop unnecessary columns
df_stock.drop(columns=['Brand Name', 'Initial Stock', 'Stock In', 'Stock Out'], inplace=True)
df_stock.head()
# Out:
#                    Stock Item        SKU  Stock On Hand   Cost  Total
# 0          GoPro HERO Session  CHDNH-B13              0  40.28   0.00
# 1    GoPro HERO6 Black Refurb  CHDNH-B17              0   0.00   0.00
# 2  GoPro HERO5 Session Refurb  CHDNH-B16             -1  69.75 -69.75
# 3    GoPro HERO5 Black Refurb  CHDNH-B15             -2   0.00   0.00
# 4    GoPro HERO4 Black Refurb  CHDNH-B11              0   0.00   0.00

# %%
# Aggregate sales data to daily level
daily_sales = df_sales.groupby('Date')['QTY'].sum().reset_index()

# %% [markdown]
# *  Adding rolling mean and rolling standard deviation features to the dataset.

# %%
# Calculate the rolling statistics
daily_sales['Rolling_Mean_7'] = daily_sales['QTY'].rolling(window=7).mean()
daily_sales['Rolling_Std_7'] = daily_sales['QTY'].rolling(window=7).std()

# Add lag features
daily_sales['Lag_1'] = daily_sales['QTY'].shift(1)
daily_sales['Lag_7'] = daily_sales['QTY'].shift(7)

daily_sales.fillna(0, inplace=True)

# Create additional time-based features
daily_sales['DayOfWeek'] = daily_sales['Date'].dt.dayofweek
daily_sales['Month'] = daily_sales['Date'].dt.month

daily_sales
# Out:
#          Date  QTY  Rolling_Mean_7  Rolling_Std_7  Lag_1  Lag_7  DayOfWeek  \
# 0  2024-10-26    5        0.000000       0.000000    0.0    0.0          5
# 1  2024-10-27    6        0.000000       0.000000    5.0    0.0          6
# 2  2024-10-28   10        0.000000       0.000000    6.0    0.0          0
# 3  2024-10-29    7        0.000000       0.000000   10.0    0.0          1
# 4  2024-10-30   14        0.000000       0.000000    7.0    0.0          2
# 5  2024-10-31   11        0.000000       0.000000   14.0    0.0          3
# 6  2024-11-01    5        8.285714       3.450328   11.0    0.0          4
# 7  2024-11-02    7        8.571429       3.207135    5.0    5.0          5
# 8  2024-11-03    5        8.428571       3.359422    7.0    6.0          6
# 9  2024-11-04   16        9.285714       4.423961    5.0   10.0          0
# 10 2024-11-05   11        9.857143       4.336995   16.0    7.0          1
# 11 2024-11-06   10        9.285714       3.946065   11.0   14.0          2
# 12 2024-11-07   43       13.857143      13.421731   10.0   11.0          3
# 13 2024-11-08   11       14.714286      12.944938   43.0    5.0          4
# 14 2024-11-09    5       14.428571      13.163803   11.0    7.0          5
# 15 2024-11-10    5       14.428571      13.163803    5.0    5.0          6
# 16 2024-11-11   23       15.428571      13.562905    5.0   16.0          0
# 17 2024-11-12    7       14.857143      13.861560   23.0   11.0          1
# 18 2024-11-13    5       14.142857      14.276187    7.0   10.0          2
# 19 2024-11-14    7        9.000000       6.531973    5.0   43.0          3
# 20 2024-11-15    7        8.428571       6.502747    7.0   11.0          4
# 21 2024-11-16    4        8.285714       6.600866    7.0    5.0          5
# 22 2024-11-17    6        8.428571       6.528327    4.0    5.0          6
# 23 2024-11-18   13        7.000000       2.886751    6.0   23.0          0
# 24 2024-11-19    8        7.142857       2.911390   13.0    7.0          1
# 25 2024-11-20   30       10.714286       8.938946    8.0    5.0          2
# 26 2024-11-21   44       16.000000      15.154757   30.0    7.0          3
# 27 2024-11-22   29       19.142857      15.258097   44.0    7.0          4
# 28 2024-11-23   10       20.000000      14.410644   29.0    4.0          5
# 29 2024-11-24   21       22.142857      13.031098   10.0    6.0          6
# 30 2024-11-25   35       25.285714      13.111246   21.0   13.0          0
# 31 2024-11-26   24       27.571429      10.783585   35.0    8.0          1
# 32 2024-11-27    8       24.428571      12.946777   24.0   30.0          2
# 33 2024-11-28    9       19.428571      10.690450    8.0   44.0          3
# 34 2024-11-29    9       16.571429      10.373960    9.0   29.0          4
# 35 2024-11-30    4       15.714286      11.220729    9.0   10.0          5
# 36 2024-12-01    8       13.857143      11.275764    4.0   21.0          6
# 37 2024-12-02   21       11.857143       7.515064    8.0   35.0          0
# 38 2024-12-03    4        9.000000       5.715476   21.0   24.0          1
# 39 2024-12-04    7        8.857143       5.756983    4.0    8.0          2
# 40 2024-12-05    4        8.142857       6.039552    7.0    9.0          3
# 41 2024-12-06    3        7.285714       6.317022    4.0    9.0          4
# 42 2024-12-07    3        7.142857       6.414270    3.0    4.0          5
# 43 2024-12-08    2        6.285714       6.676184    3.0    8.0          6
# 44 2024-12-09   12        5.000000       3.464102    2.0   21.0          0
# 45 2024-12-10    5        5.142857       3.436499   12.0    4.0          1
# 46 2024-12-11    6        5.000000       3.366502    5.0    7.0          2
# 47 2024-12-12    4        5.000000       3.366502    6.0    4.0          3
# 48 2024-12-13    6        5.428571       3.258688    4.0    3.0          4
# 49 2024-12-14    2        5.285714       3.401680    6.0    3.0          5
# 50 2024-12-15    1        5.142857       3.579040    2.0    2.0          6
# 51 2024-12-16   11        5.000000       3.265986    1.0   12.0          0
# 52 2024-12-17   12        6.000000       4.203173   11.0    5.0          1
# 53 2024-12-19    1        5.285714       4.608481   12.0    6.0          3
#
#     Month
# 0      10
# 1      10
# 2      10
# 3      10
# 4      10
# 5      10
# 6      11
# 7      11
# 8      11
# 9      11
# 10     11
# 11     11
# 12     11
# 13     11
# 14     11
# 15     11
# 16     11
# 17     11
# 18     11
# 19     11
# 20     11
# 21     11
# 22     11
# 23     11
# 24     11
# 25     11
# 26     11
# 27     11
# 28     11
# 29     11
# 30     11
# 31     11
# 32     11
# 33     11
# 34     11
# 35     11
# 36     12
# 37     12
# 38     12
# 39     12
# 40     12
# 41     12
# 42     12
# 43     12
# 44     12
# 45     12
# 46     12
# 47     12
# 48     12
# 49     12
# 50     12
# 51     12
# 52     12
# 53     12

# %% [markdown]
# Applying StandardScaler to the dataset.
# - StandardScaler is used to standardize the features by removing the mean and scaling to unit variance.
# - StandardScaler is applied to the features of the dataset.

# %%
# Normalize the data using StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(daily_sales[['QTY', 'Rolling_Mean_7', 'Rolling_Std_7', 'Lag_1', 'Lag_7', 'DayOfWeek', 'Month']])

# %% [markdown]
# Splitting the dataset into training and testing datasets.
#    - The dataset is split into training and testing datasets.
#    - The training dataset is used to train the model.
#    - The testing dataset is used to evaluate the model.
#    - The testing dataset is used to predict the stock replenishment for the next 30 days.

# %%
# Prepare sequences for BiLSTM and Gradient Boosting models
sequence_length = 14
num_features = scaled_data.shape[1]

X, y = [], []
for i in range(len(scaled_data) - sequence_length):
    X.append(scaled_data[i:i+sequence_length])
    y.append(scaled_data[i+sequence_length, 0])

X, y = np.array(X), np.array(y)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False, random_state=42)

# %% [markdown]
# Building a Stacked LSTM-RHN model.
#    - The Stacked LSTM-RHN model is built using the Keras library.
#    - The model is trained on the training dataset.
#    - The model is used to predict the stock replenishment for the next 30 days.

# %%
# Build the LSTM model
def build_lstm_model(hp):
    model = Sequential()

    # Add LSTM layer
    model.add(LSTM(units=hp.Int('units', min_value=64, max_value=512, step=32),
                 input_shape=(sequence_length, num_features), return_sequences=False))
    model.add(Dropout(hp.Float('dropout', min_value=0.1, max_value=0.5, step=0.1)))

    # Add Dense layer
    model.add(Dense(units=hp.Int('dense_units', min_value=64, max_value=512, step=32), activation='relu'))
    model.add(Dropout(hp.Float('dense_dropout', min_value=0.1, max_value=0.5, step=0.1)))

    # Output layer
    model.add(Dense(1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Initialize the tuner
tuner_lstm = kt.RandomSearch(
    build_lstm_model,
    objective='val_loss',
    max_trials=12,
    executions_per_trial=4,
    directory='lstm_tuner',
    project_name='lstm_model'
)
# Out:
# INFO:tensorflow:Reloading Tuner from lstm_tuner\lstm_model\tuner0.json

# %%
# Search for the best hyperparameters
tuner_lstm.search(X_train, y_train, epochs=50, validation_split=0.2)

# Get the best hyperparameters and the model
best_hps_lstm = tuner_lstm.get_best_hyperparameters()[0]
lstm_model = tuner_lstm.hypermodel.build(best_hps_lstm)

# Train the final LSTM model
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lstm_model.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopping], batch_size=32)

# Make predictions
lstm_test_pred = lstm_model.predict(X_test)
# Out:
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.3515 - val_loss: 0.4722
# Epoch 2/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3084 - val_loss: 0.4157
# Epoch 3/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.2721 - val_loss: 0.3807
# Epoch 4/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.1885 - val_loss: 0.3577
# Epoch 5/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1718 - val_loss: 0.3493
# Epoch 6/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0844 - val_loss: 0.3450
# Epoch 7/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0556 - val_loss: 0.3492
# Epoch 8/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0004 - val_loss: 0.3676
# Epoch 9/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.9905 - val_loss: 0.4075
# Epoch 10/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8202 - val_loss: 0.4700
# Epoch 11/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.9102 - val_loss: 0.5611
# Epoch 12/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8578 - val_loss: 0.7012
# Epoch 13/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.7027 - val_loss: 0.9043
# Epoch 14/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7398 - val_loss: 1.1247
# Epoch 15/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6310 - val_loss: 1.4651
# Epoch 16/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.7072 - val_loss: 1.7340
# 1/1 [==============================] - 0s 374ms/step

# %%
# Define CNN model
def build_cnn_model(hp):
    model = Sequential()

    # Add Conv1D layer
    model.add(Conv1D(filters=hp.Int('filters', min_value=32, max_value=512, step=32),
                     kernel_size=hp.Int('kernel_size', min_value=2, max_value=5, step=32),
                     activation='relu', input_shape=(sequence_length, num_features)))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Conv1D(filters=hp.Int('filters2', min_value=32, max_value=512, step=32),
                     kernel_size=hp.Int('kernel_size2', min_value=2, max_value=5, step=32),
                     activation='relu', input_shape=(sequence_length, num_features)))
    model.add(MaxPooling1D(pool_size=2))

    # Flatten the output
    model.add(Flatten())

    # Add Dense layer
    model.add(Dense(units=hp.Int('dense_units', min_value=32, max_value=512, step=32), activation='relu'))
    model.add(Dropout(hp.Float('dense_dropout', min_value=0.1, max_value=0.5, step=0.1)))

    # Output layer
    model.add(Dense(1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Initialize the tuner
tuner_cnn = kt.RandomSearch(
    build_cnn_model,
    objective='val_loss',
    max_trials=12,
    executions_per_trial=2,
    directory='cnn_tuner',
    project_name='cnn_model'
)
# Out:
# INFO:tensorflow:Reloading Tuner from cnn_tuner\cnn_model\tuner0.json

# %%
# Search for the best hyperparameters
tuner_cnn.search(X_train, y_train, epochs=50, validation_split=0.2)

# Get the best hyperparameters and the model
best_hps_cnn = tuner_cnn.get_best_hyperparameters()[0]
cnn_model = tuner_cnn.hypermodel.build(best_hps_cnn)

# Train the final CNN model
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
cnn_model.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopping], batch_size=32)

# Make predictions
cnn_test_pred = cnn_model.predict(X_test)
# Out:
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 1.3523 - val_loss: 1.0594
# Epoch 2/100
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0148 - val_loss: 1.5545
# Epoch 3/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8314 - val_loss: 2.0458
# Epoch 4/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.7304 - val_loss: 2.4070
# Epoch 5/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6257 - val_loss: 2.6003
# Epoch 6/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6725 - val_loss: 2.7856
# Epoch 7/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5754 - val_loss: 3.1028
# Epoch 8/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5047 - val_loss: 3.4675
# Epoch 9/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5016 - val_loss: 3.6434
# Epoch 10/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4058 - val_loss: 3.7366
# Epoch 11/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4001 - val_loss: 3.5556
# 1/1 [==============================] - 0s 83ms/step

# %%
# Combine the predictions using column stacking
stacked_predictions = np.column_stack((lstm_test_pred.flatten(), cnn_test_pred.flatten()))

# Train a final regressor on the stacked predictions
final_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
final_regressor.fit(stacked_predictions, y_test)

# Make predictions on the test set
final_pred = final_regressor.predict(stacked_predictions)

# Inverse transform the predictions
final_pred_rescaled = scaler.inverse_transform(np.column_stack([final_pred.reshape(-1, 1),
                                                                np.zeros((final_pred.shape[0], num_features - 1))]))[:, 0]

# %%
# Calculate the evaluation metrics
mae = mean_absolute_error(scaler.inverse_transform(np.column_stack([y_test.reshape(-1, 1),
                                np.zeros((y_test.shape[0], num_features - 1))]))[:, 0], final_pred_rescaled)
mse = mean_squared_error(scaler.inverse_transform(np.column_stack([y_test.reshape(-1, 1),
                                np.zeros((y_test.shape[0], num_features - 1))]))[:, 0], final_pred_rescaled)
r2 = r2_score(scaler.inverse_transform(np.column_stack([y_test.reshape(-1, 1),
                                np.zeros((y_test.shape[0], num_features - 1))]))[:, 0], final_pred_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error: {mae:.2f}')
print(f'Mean Squared Error: {mse:.2f}')
print(f'R2 Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
# Out:
# Mean Absolute Error: 1.29
# Mean Squared Error: 2.40
# R2 Score: 0.85
# Root Mean Squared Error: 1.55

# %%
# Forecast next 30 days
future_predictions = []
last_sequence = scaled_data[-sequence_length:]

for _ in range(30):
    # Predict the next value using LSTM and CNN models
    lstm_next_pred = lstm_model.predict(last_sequence.reshape(1, sequence_length, num_features))
    cnn_next_pred = cnn_model.predict(last_sequence.reshape(1, sequence_length, num_features))

    # Combine the predictions using column stacking
    stacked_next_pred = np.column_stack((lstm_next_pred.flatten(), cnn_next_pred.flatten()))
    final_next_pred = final_regressor.predict(stacked_next_pred)

    # Store the final prediction
    future_predictions.append(final_next_pred)

    # Update the sequence
    next_input = np.concatenate([last_sequence[-1, :-1], final_next_pred])
    last_sequence = np.vstack([last_sequence[1:], next_input])

# Convert the future predictions to a single array
future_predictions = np.array(future_predictions).reshape(-1, 1)

# Concatenate zeros to match the original feature shape for inverse transformation
future_predictions_full = np.column_stack([future_predictions, np.zeros((future_predictions.shape[0], num_features - 1))])

# Inverse transform the predictions
future_predictions_rescaled = scaler.inverse_transform(future_predictions_full)
future_predictions_units = future_predictions_rescaled[:, 0]
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
# Plot the results
plt.figure(figsize=(20, 12))
plt.plot(daily_sales['Date'], daily_sales['QTY'], label='Historical Sales')
future_dates = pd.date_range(start=daily_sales['Date'].max() + pd.Timedelta(days=1), periods=30)
plt.plot(future_dates, future_predictions_units, label='Forecasted Sales', linestyle='--', color='#168e72', linewidth=2)
plt.xlabel('Date', fontsize=15)
plt.ylabel('Units', fontsize=15)
plt.title('Stock Inventory Replenishment Forecast with Stacked LSTM-CNN Model', fontsize=20)
plt.legend()
plt.show()

# %%
# Calculate the actual units sold for each SKU in the last 30 days
last_30_days_sales = df_sales[df_sales['Date'] > df_sales['Date'].max() - pd.Timedelta(days=30)]
last_30_days_sales = last_30_days_sales.groupby(['SKU', 'Product Name'])['QTY'].sum().reset_index()
last_30_days_sales.columns = ['SKU', 'Product Name','Last_30_Days_Sales']

# Get the current stock levels for each SKU
current_stock_levels = df_stock.groupby('SKU')['Stock On Hand'].sum().reset_index()
current_stock_levels.columns = ['SKU', 'Current_Stock']

# Merge the last 30 days sales and current stock levels
restock_skus = pd.merge(last_30_days_sales, current_stock_levels, on='SKU')

# Calculate the forecasted demand for the next 30 days based on the model's forecast
average_daily_forecast = future_predictions_units.mean()

# Calculate restock quantity considering forecasted demand and current stock
restock_skus['Restock_Quantity'] = restock_skus.apply(
    lambda x: max(0, x['Last_30_Days_Sales'] - x['Current_Stock'] + average_daily_forecast), axis=1
)

# Set Restock Quantity to whole integer values (rounded up)
restock_skus['Restock_Quantity'] = restock_skus['Restock_Quantity'].apply(np.ceil).astype(int)

# Adjust Restock Quantity to be in multiples of 6
restock_skus['Restock_Quantity'] = restock_skus['Restock_Quantity'].apply(lambda x: x + (6 - x % 6) if x % 6 != 0 else x)

# Ensure Restock Quantity is zero if Current Stock is greater than or equal to Forecasted Demand
restock_skus['Restock_Quantity'] = restock_skus.apply(
    lambda x: 0 if x['Current_Stock'] >= x['Last_30_Days_Sales'] else x['Restock_Quantity'], axis=1
)

# Restock quantity not required for SKUs start with 'UKRFB
restock_skus = restock_skus[~restock_skus['SKU'].str.startswith('UKRFB')]

# Restock quantity not required for SKUs start with 'DERFB'
restock_skus = restock_skus[~restock_skus['SKU'].str.startswith('DERFB')]

# Restock quantity not required for SKUs ends with '- R'
restock_skus = restock_skus[~restock_skus['SKU'].str.endswith('- R')].reset_index(drop=True)

# Display the SKUs that need restocking with the calculated restock quantities
print("SKUs that need restocking with required quantities:")
display(restock_skus[['SKU', 'Product Name', 'Last_30_Days_Sales', 'Current_Stock', 'Restock_Quantity']])
# Out:
# SKUs that need restocking with required quantities:
#                   SKU                                       Product Name  \
# 0           AACFT-001                GoPro Curved + Flat Adhesive Mounts
# 1           ABSSC-002                                        GoPro Casey
# 2           ACBAT-011                                 MAX Enduro Battery
# 3        ACDBD-011-EU          MAX Dual Battery Charger + Enduro Battery
# 4           ACHOM-002                                     Head Strap 2.0
# 5           ACMPM-001                             GoPro Jaws: Flex Clamp
# 6           ADBAT-011  GoPro Enduro Rechargeable Li-Ion Battery for H...
# 7           ADCOD-001                USB Pass-Through Door (HERO9 Black)
# 8           ADFMD-001                            Media Mod (HERO9 Black)
# 9           ADWAL-001                           HERO9 BLACK Max Lens Mod
# 10          AEBAT-001                            Enduro for HERO13 Black
# 11          AEBAT-201                   Enduro (2 Pack) for HERO13 Black
# 12       AEDBD-201-EU                Dual Battery Charger (HERO13 Black)
# 13          AEWAL-001                                Ultra Wide Lens Mod
# 14          AFTTM-001        GoPro Shorty (Mini Extension Pole + Tripod)
# 15          AGBAG-002                                     GoPro Grab Bag
# 16          AGCHM-001             GoPro Chesty (Performance Chest Mount)
# 17          AGTLM-001       Large Tube Mount (Roll  Bars + Pipes + More)
# 18          AHDAF-303                                    Antifog Inserts
# 19          AHWBM-002                                 Hand + Wrist Strap
# 20          AKTAC-001                                         Sports Kit
# 21       ARMTE-003-EU                               Smart Remote - GoPro
# 22          ATCLP-001                               Magnetic Swivel Clip
# 23          AUCMT-302                                        Suction Cup
# 24       CHDFB-121-EU                       HERO12 Black Creator Edition
# 25       CHDFB-131-EU                       GoPro HERO13 Creator Edition
# 26       CHDHF-111-RW                                  HERO11 Black Mini
# 27       CHDHF-131-EU                                         GoPro HERO
# 28       CHDHX-102-RT    GoPro HERO10 Black (Without the the Carry Case)
# 29       CHDHX-112-RW                                      HERO11 Black
# 30       CHDHX-121-RW                                       HERO12 Black
# 31       CHDHX-131-RW                                 GoPro HERO13 Black
# 32  CHDHX-131-RW-SWAG                     GoPro HERO13 Black SWAG Bundle
# 33       CHDRB-131-RW                GoPro HERO13 Black Accessory Bundle
# 34        GPCARRY-001                           GoPro Carry Case (Loose)
#
#     Last_30_Days_Sales  Current_Stock  Restock_Quantity
# 0                    6              4                12
# 1                   25              1                30
# 2                    3             12                 0
# 3                   10              4                12
# 4                    8              2                12
# 5                    7             10                 0
# 6                   12              2                18
# 7                    9              5                12
# 8                   12              2                18
# 9                    7              2                12
# 10                   4             60                 0
# 11                   6              0                12
# 12                  16              3                18
# 13                   1              6                 0
# 14                  13              0                18
# 15                   1              4                 0
# 16                  17              2                24
# 17                   1              5                 0
# 18                   1              4                 0
# 19                   7              1                12
# 20                   2              2                 0
# 21                   3              6                 0
# 22                   3              2                 6
# 23                   5              1                12
# 24                   4              7                 0
# 25                  25              9                24
# 26                   1              1                 0
# 27                  21              2                24
# 28                   8              3                12
# 29                   8              1                12
# 30                  21              0                30
# 31                  18             48                 0
# 32                  11              0                18
# 33                  36              2                42
# 34                   1             25                 0

# %%
average_daily_forecast
# Out:
# 4.535333333333345

# %%
# Highlight the SKUs that need restocking above a certain threshold with a color
def highlight_restock(x):
    color = 'background-color: #12A189' if x['Restock_Quantity'] > 0 else ''
    return [color for _ in x]

restock_skus.style.apply(highlight_restock, axis=1)
# Out:
# <style type="text/css">
# #T_c9643_row0_col0, #T_c9643_row0_col1, #T_c9643_row0_col2, #T_c9643_row0_col3, #T_c9643_row0_col4, #T_c9643_row1_col0, #T_c9643_row1_col1, #T_c9643_row1_col2, #T_c9643_row1_col3, #T_c9643_row1_col4, #T_c9643_row3_col0, #T_c9643_row3_col1, #T_c9643_row3_col2, #T_c9643_row3_col3, #T_c9643_row3_col4, #T_c9643_row4_col0, #T_c9643_row4_col1, #T_c9643_row4_col2, #T_c9643_row4_col3, #T_c9643_row4_col4, #T_c9643_row6_col0, #T_c9643_row6_col1, #T_c9643_row6_col2, #T_c9643_row6_col3, #T_c9643_row6_col4, #T_c9643_row7_col0, #T_c9643_row7_col1, #T_c9643_row7_col2, #T_c9643_row7_col3, #T_c9643_row7_col4, #T_c9643_row8_col0, #T_c9643_row8_col1, #T_c9643_row8_col2, #T_c9643_row8_col3, #T_c9643_row8_col4, #T_c9643_row9_col0, #T_c9643_row9_col1, #T_c9643_row9_col2, #T_c9643_row9_col3, #T_c9643_row9_col4, #T_c9643_row11_col0, #T_c9643_row11_col1, #T_c9643_row11_col2, #T_c9643_row11_col3, #T_c9643_row11_col4, #T_c9643_row12_col0, #T_c9643_row12_col1, #T_c9643_row12_col2, #T_c9643_row12_col3, #T_c9643_row12_col4, #T_c9643_row14_col0, #T_c9643_row14_col1, #T_c9643_row14_col2, #T_c9643_row14_col3, #T_c9643_row14_col4, #T_c9643_row16_col0, #T_c9643_row16_col1, #T_c9643_row16_col2, #T_c9643_row16_col3, #T_c9643_row16_col4, #T_c9643_row19_col0, #T_c9643_row19_col1, #T_c9643_row19_col2, #T_c9643_row19_col3, #T_c9643_row19_col4, #T_c9643_row22_col0, #T_c9643_row22_col1, #T_c9643_row22_col2, #T_c9643_row22_col3, #T_c9643_row22_col4, #T_c9643_row23_col0, #T_c9643_row23_col1, #T_c9643_row23_col2, #T_c9643_row23_col3, #T_c9643_row23_col4, #T_c9643_row25_col0, #T_c9643_row25_col1, #T_c9643_row25_col2, #T_c9643_row25_col3, #T_c9643_row25_col4, #T_c9643_row27_col0, #T_c9643_row27_col1, #T_c9643_row27_col2, #T_c9643_row27_col3, #T_c9643_row27_col4, #T_c9643_row28_col0, #T_c9643_row28_col1, #T_c9643_row28_col2, #T_c9643_row28_col3, #T_c9643_row28_col4, #T_c9643_row29_col0, #T_c9643_row29_col1, #T_c9643_row29_col2, #T_c9643_row29_col3, #T_c9643_row29_col4, #T_c9643_row30_col0, #T_c9643_row30_col1, #T_c9643_row30_col2, #T_c9643_row30_col3, #T_c9643_row30_col4, #T_c9643_row32_col0, #T_c9643_row32_col1, #T_c9643_row32_col2, #T_c9643_row32_col3, #T_c9643_row32_col4, #T_c9643_row33_col0, #T_c9643_row33_col1, #T_c9643_row33_col2, #T_c9643_row33_col3, #T_c9643_row33_col4 {
#   background-color: #12A189;
# }
# </style>
# <table id="T_c9643">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9643_level0_col0" class="col_heading level0 col0" >SKU</th>
#       <th id="T_c9643_level0_col1" class="col_heading level0 col1" >Product Name</th>
#       <th id="T_c9643_level0_col2" class="col_heading level0 col2" >Last_30_Days_Sales</th>
#       <th id="T_c9643_level0_col3" class="col_heading level0 col3" >Current_Stock</th>
#       <th id="T_c9643_level0_col4" class="col_heading level0 col4" >Restock_Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9643_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9643_row0_col0" class="data row0 col0" >AACFT-001</td>
#       <td id="T_c9643_row0_col1" class="data row0 col1" >GoPro Curved + Flat Adhesive Mounts</td>
#       <td id="T_c9643_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_c9643_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_c9643_row0_col4" class="data row0 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9643_row1_col0" class="data row1 col0" >ABSSC-002</td>
#       <td id="T_c9643_row1_col1" class="data row1 col1" >GoPro Casey</td>
#       <td id="T_c9643_row1_col2" class="data row1 col2" >25</td>
#       <td id="T_c9643_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_c9643_row1_col4" class="data row1 col4" >30</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c9643_row2_col0" class="data row2 col0" >ACBAT-011</td>
#       <td id="T_c9643_row2_col1" class="data row2 col1" >MAX Enduro Battery</td>
#       <td id="T_c9643_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_c9643_row2_col3" class="data row2 col3" >12</td>
#       <td id="T_c9643_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c9643_row3_col0" class="data row3 col0" >ACDBD-011-EU</td>
#       <td id="T_c9643_row3_col1" class="data row3 col1" >MAX Dual Battery Charger + Enduro Battery</td>
#       <td id="T_c9643_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_c9643_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_c9643_row3_col4" class="data row3 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c9643_row4_col0" class="data row4 col0" >ACHOM-002</td>
#       <td id="T_c9643_row4_col1" class="data row4 col1" >Head Strap 2.0</td>
#       <td id="T_c9643_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_c9643_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_c9643_row4_col4" class="data row4 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c9643_row5_col0" class="data row5 col0" >ACMPM-001</td>
#       <td id="T_c9643_row5_col1" class="data row5 col1" >GoPro Jaws: Flex Clamp</td>
#       <td id="T_c9643_row5_col2" class="data row5 col2" >7</td>
#       <td id="T_c9643_row5_col3" class="data row5 col3" >10</td>
#       <td id="T_c9643_row5_col4" class="data row5 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c9643_row6_col0" class="data row6 col0" >ADBAT-011</td>
#       <td id="T_c9643_row6_col1" class="data row6 col1" >GoPro Enduro Rechargeable Li-Ion Battery for HERO9/10 Black</td>
#       <td id="T_c9643_row6_col2" class="data row6 col2" >12</td>
#       <td id="T_c9643_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_c9643_row6_col4" class="data row6 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c9643_row7_col0" class="data row7 col0" >ADCOD-001</td>
#       <td id="T_c9643_row7_col1" class="data row7 col1" >USB Pass-Through Door (HERO9 Black)</td>
#       <td id="T_c9643_row7_col2" class="data row7 col2" >9</td>
#       <td id="T_c9643_row7_col3" class="data row7 col3" >5</td>
#       <td id="T_c9643_row7_col4" class="data row7 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c9643_row8_col0" class="data row8 col0" >ADFMD-001</td>
#       <td id="T_c9643_row8_col1" class="data row8 col1" >Media Mod (HERO9 Black)</td>
#       <td id="T_c9643_row8_col2" class="data row8 col2" >12</td>
#       <td id="T_c9643_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_c9643_row8_col4" class="data row8 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c9643_row9_col0" class="data row9 col0" >ADWAL-001</td>
#       <td id="T_c9643_row9_col1" class="data row9 col1" >HERO9 BLACK Max Lens Mod</td>
#       <td id="T_c9643_row9_col2" class="data row9 col2" >7</td>
#       <td id="T_c9643_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_c9643_row9_col4" class="data row9 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c9643_row10_col0" class="data row10 col0" >AEBAT-001</td>
#       <td id="T_c9643_row10_col1" class="data row10 col1" >Enduro for HERO13 Black</td>
#       <td id="T_c9643_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_c9643_row10_col3" class="data row10 col3" >60</td>
#       <td id="T_c9643_row10_col4" class="data row10 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c9643_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c9643_row11_col0" class="data row11 col0" >AEBAT
